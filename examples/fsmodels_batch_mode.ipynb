# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
from joblib import Parallel, delayed

from matplotlib import pyplot as plt
from os import listdir
import pandas as pd

import tensorflow as tf
import numpy as np

from fsmodels import SklSingleExpFrequencyScan

from fsplots import plot_model
from fsplots import plot_loss_path
from fsplots import plot_experimental_points

# %matplotlib inline

# %%
def get_file_names(datasets_folder):
    return [datasets_folder + '/' + _ for _ in listdir(datasets_folder)]

# %%
def read_datasets(file_names):
    return [[f_name, pd.read_csv(f_name,
                                 header=0,
                                 parse_dates=[0],
                                 infer_datetime_format=True)]
            for f_name in file_names]

# %%
def fit_model(df):
    
    freq_values = df.frequency_hz.to_numpy()
    freq_powers = np.log10(freq_values)
    
    dlts_values = df.dlts_pf.to_numpy()
    f_pulse_value = float(df.f_pulse[0]) * 10 ** (-6)
    
    
    max_abs_index = np.absolute(dlts_values).argmax()
    extrem_val = dlts_values[max_abs_index]
    
    new_max_dlts = freq_powers.max()

    normalize = lambda x: x / extrem_val * new_max_dlts
    denormalize = lambda x: x * extrem_val / new_max_dlts
    
    dlts_values = normalize(dlts_values)

    model = SklSingleExpFrequencyScan(filling_pulse = f_pulse_value,
                                      fit_p_coef = True,
                                      learning_rate = 0.05,
                                      n_iters = 1000, 
                                      stop_val = 10**-10,
                                      verbose = False
                                     )
    
    model.fit(X=freq_powers, y=dlts_values)
    
    fit_results_ = model.fit_results_
    fit_results_.amplitude_0 = denormalize(fit_results_.amplitude_0)
    
    return fit_results_

# %%
def get_additional_text(df, fit_results_):

    def text_params(fit_result, actual_dlts, frequency_powers):
        time_constant_power = fit_result.time_constant_pow_0
        f_pulse = fit_result.filling_pulse
        p = fit_result.p_coef
        amp = fit_result.amplitude_0
        mse = fit_result.loss

        text = '\n'.join(['$\\log_{10}(\\tau)$ = ' + f'{time_constant_power:.4f} ' + '$\\log_{10}$(с)',
                          f'$\\tau$ = {10**time_constant_power:.4e} с',
                          f'$A$ = {amp:.4e} пФ',
                          f'$p$ = {p:.4f}',
                          f'MSE = {mse:.4e} $пФ^2$',
                          f'RMSE = {np.sqrt(mse):.4e} пФ'
                         ])

        return text

    
    frequency_powers = np.log10(df.frequency_hz.to_numpy())
    dlts_values = df.dlts_pf.to_numpy()
    f_pulse = df.f_pulse[0] * 10 ** (-6)
    
    text_1 = '\n'.join([f'Образец: {df.specimen_name[0]}',
                        f'$T$ = {df.temperature_k.mean():.1f} К',
                        f'$U_1$={df.u1[0]} В',
                        f'$U_R$={df.ur[0]} В',
                        f'$t_1$ = {f_pulse:.4e} с'
                       ])
    
    text_2 = '\n'.join(['Начальные значения:', text_params(fit_results_.iloc[0, :], dlts_values, frequency_powers)])
    text_3 = '\n'.join(['Конечные значения:', text_params(fit_results_.iloc[-1, :], dlts_values, frequency_powers)])
    
    return text_1, text_2, text_3


def print_results(df, fit_results_):
    
    frequency = df.frequency_hz.to_numpy()
    frequency_powers = np.log10(frequency)
    actual_dlts = df.dlts_pf.to_numpy()
    
    fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))

    ax0 = plot_model(X = frequency_powers, 
                     y = actual_dlts, 
                     model_class = SklSingleExpFrequencyScan,
                     fit_results_ = fit_results_, 
                     plot_exps = False,
                     ax=ax0
                    )

    ax1 = plot_loss_path(fit_results_, ax=ax1)
    
    title = f'{df.specimen_name[0]} T={df.temperature_k.mean():.1f} K, $U_1$={df.u1[0]} V, $U_R$={df.ur[0]} V'
    plt.suptitle(title, y=1.01)
    
    text_1, text_2, text_3 = get_additional_text(df, fit_results_)
    text = '\n\n'.join([text_1, text_3])
    
    
    x = 0.4 * (max(ax1.get_xlim()) - min(ax1.get_xlim())) + min(ax1.get_xlim())
    y = 0.95 * max(ax1.get_ylim())
    fontsize=10
    bbox_dict = {'facecolor':'white', 'alpha':0.8, 'edgecolor':'gray'}
        
    ax1.text(x, y, text, fontsize=fontsize, verticalalignment='top', bbox=bbox_dict)
    
    return fig, (ax0, ax1)

# %%
DATASET_PATH = '../dataset'
PLOTS_PATH = '../plots'
MODELS_PATH = '../models'

# %%
fnames = get_file_names(DATASET_PATH)
df_list = read_datasets(fnames)

# %%
def batch_processing(f_name, df):
    
    fit_results_ = fit_model(df)
    
    fig, ax = print_results(df=df,
                            fit_results_=fit_results_)

    frequency_powers = np.log10(df.frequency_hz.to_numpy())
    
    final_model = SklSingleExpFrequencyScan(filling_pulse=fit_results_.filling_pulse.iloc[-1])
    
    last_row = fit_results_.iloc[-1]
    
    final_model.exps_params_ = [ [ last_row.time_constant_pow_0, last_row.amplitude_0 ] ]
    
    final_model.p_coef_ = last_row.p_coef
    
    model_df = df.copy()
    
    model_df['dlts_pf_model'] = final_model.predict(frequency_powers)
    model_df['p_coef_model'] = final_model.p_coef_
    
    if model_df['p_coef_model'].isna().any():
        message = MODELS_PATH + '/' + f_name.split('/')[-1].rstrip('.csv') + '_model - ERROR'
    else:
        message = MODELS_PATH + '/' + f_name.split('/')[-1].rstrip('.csv') + '_model - OK'
    
    model_df['time_constant_power_model'] = final_model.exps_params_[0, 0]
    model_df['time_constant_model'] = 10 ** final_model.exps_params_[0, 0]
    model_df['amplitude_model'] = final_model.exps_params_[0, 1]
    
    mse = np.square(df.dlts_pf.to_numpy() - final_model.predict(frequency_powers)).mean()
    model_df['rmse_model'] = np.sqrt(mse)
    
    file_name = MODELS_PATH + '/' + f_name.split('/')[-1].rstrip('.csv') + '_model' + '.csv'
    model_df.to_csv(file_name, index=False)
    
    file_name = PLOTS_PATH + '/' + f_name.split('/')[-1].rstrip('.csv') + '_model' + '.pdf'
    plt.savefig(file_name, bbox_inches='tight')
    
    file_name = PLOTS_PATH + '/' + f_name.split('/')[-1].rstrip('.csv') + '_model' + '.jpg'
    plt.savefig(file_name, bbox_inches='tight')
    
    plt.close('all')
    
    return message
    
    
messages = Parallel(n_jobs=-1)(delayed(batch_processing)(f_name, df) for f_name, df in df_list)
messages
# Out:
# 2022-09-21 06:16:53.075958: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.076313: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.076323: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.076548: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.076574: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.076632: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.076869: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.142203: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.142294: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.142324: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.142529: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.142582: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.142616: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.142847: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.206473: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.206557: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.206609: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.206833: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.206888: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.206919: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.207172: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.215147: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.215198: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.215206: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.215428: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.215458: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.215465: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.215677: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.226172: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.226202: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.226209: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.226396: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.226421: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.226428: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.226622: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.261538: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.261633: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.261664: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.261858: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.261909: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.261943: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.262162: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.272110: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.272207: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.272250: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.272463: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.272513: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.272545: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.272759: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.273522: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.273604: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.273633: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.273843: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.273891: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.273919: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.274139: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.279144: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.279253: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.279282: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.279513: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.279557: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.279564: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.279771: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.294437: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.294471: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.294480: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.294663: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.294683: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.294690: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.294880: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.325517: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.325619: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.325645: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.325870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.325920: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.325948: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.326179: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.342264: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.342292: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.342323: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.342329: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.342533: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.342556: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.342562: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.342629: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.342643: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.342786: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.342926: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.342976: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.342986: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.343231: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.346366: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.346523: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.346583: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.346841: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.346924: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.346986: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.347274: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.348766: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.348854: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.348903: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.349147: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.349208: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.349254: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.349480: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.350920: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.351033: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.351112: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.361958: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.362054: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.362085: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.362345: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.362395: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.362425: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.362675: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.364010: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.364040: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.364047: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.364311: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.364342: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.364349: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.364534: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.364976: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.365043: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.365050: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.365229: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.365270: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.365277: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.365463: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.367749: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.367853: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.367880: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.368326: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.368353: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.368360: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.368589: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.378596: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.378676: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.378700: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.378902: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.378945: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.378966: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.379198: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.379228: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.379286: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.379295: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.379495: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.439130: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.439183: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.439191: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.439399: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.439435: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.439444: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.439639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.445830: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.445980: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.446043: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.446266: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.446344: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.446406: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.446656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 06:16:53.502253: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:16:53.502291: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:16:53.502299: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:16:53.506589: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:16:53.506651: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:16:53.506659: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:16:53.506874: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ['../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_-10С_-3В-4В_10мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-1В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-1В-5В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_+10С_-4В-5В_50мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-0В-2В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-0В-3В_200мВ_10мкс_шаг_0,1_model - ERROR',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-0В-4В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-4В-5В_50мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_-10С_-2В-3В_20мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-1В-3В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-0В-2В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_+30С_-0В-1В_5мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-2В-4В_500мВ_10мкс_шаг_0,1_model - ERROR',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-0В-3В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-2В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-1В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-0В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-2В-4В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-1В-4В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-1В-4В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-2В-5В_200мВ_10мкс_шаг_0,1_model - ERROR',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-3В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_+10С_-0В-1В_5мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_-10С_-0В-1В_5мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-1В-3В_500мВ_10мкс_шаг_0,1_model - ERROR',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-0В-3В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_+10С_-1В-2В_200мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_-10С_-1В-2В_50мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_1пФ_-10С_-4В-5В_10мВ_10мкс_шаг_0,01_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-1В-4В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-0В-4В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-1В-2В_50мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-3В-5В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-1В-3В_200мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-3В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-0В-2В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_-10С_-0В-5В_200мВ_10мкс_шаг_0,1_model - ERROR',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-2В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-3В-4В_50мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-3В-4В_10мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-2В-4В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-2В-3В_20мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-0В-5В_500мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+30С_-2В-3В_50мВ_10мкс_шаг_0,1_model - OK',
#  '../models/1564ЛЕ1№1_п1_2500Гц-1Гц_10пФ_+10С_-0В-4В_500мВ_10мкс_шаг_0,1_model - OK']
