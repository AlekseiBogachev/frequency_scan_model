# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

from pydlts.fsmodels import SklMultiExpFrequencyScan
from pydlts.fsplots import plot_experimental_points
from pydlts.fsplots import plot_model

# %% [markdown]
# # Проверка прототипа модели на частотном скане из 3 экспоненциальных составляющих

# %%
f_pulse = 20 * 10**-6
fs = SklMultiExpFrequencyScan(n_exps=3, filling_pulse = f_pulse)

fs.exps_params_=[[-1.0, 3.5],
                 [-2.3, 3.0],
                 [-3.5, 2.5]]
# Out:
# 2022-10-10 02:31:10.311138: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-10-10 02:31:10.311160: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-10-10 02:31:10.311165: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-10-10 02:31:10.311306: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-10-10 02:31:10.311318: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-10-10 02:31:10.311321: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# ...

# %%
X = np.linspace(0, 3.5, 200)
y = fs.predict(X) 
y += np.random.normal(loc=0, scale=0.2, size=y.shape[0])

# %%
plot_experimental_points(X, y)
plt.show()

# %%
n_exps = 3

initial_exps_params_ = [[-1.5, 1.5],
                        [-2.0, 1.0],
                        [-3.0, 1.0]
                       ]

fs = SklMultiExpFrequencyScan(filling_pulse = f_pulse,                           
                              n_exps=n_exps,
                              n_iters=200,
                              stop_val=10**-5,
                              verbose=True
                             )

fs.fit(X, y, initial_exps_params_=initial_exps_params_)
# Out:
# iteration # 0
# loss: 2.663078977594389
# exps_params:
# [[-1.5  1.5]
#  [-2.   1. ]
#  [-3.   1. ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 2.34659400212748
# exps_params:
# [[-1.4440579   1.61109342]
#  [-2.01373854  1.10424235]
#  [-2.98890091  1.11383417]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 2.0606891237614233
# exps_params:
# [[-1.3805856   1.71446258]
#  [-2.03068817  1.19938547]
#  [-2.98150671  1.21995423]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 1.8025130808788146
# exps_params:
# [[-1.31443244  1.81198819]
#  [-2.04987801  1.28761019]
#  [-2.97752958  1.31891739]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# ...

# %%
plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.show()

# %%
fit_results = fs.fit_results_
fit_results
# Out:
#      amplitude_0  amplitude_1  amplitude_2  filling_pulse  learning_rate  \
# 0       1.500000     1.000000     1.000000        0.00002            0.1
# 1       1.611093     1.104242     1.113834        0.00002            0.1
# 2       1.714463     1.199385     1.219954        0.00002            0.1
# 3       1.811988     1.287610     1.318917        0.00002            0.1
# 4       1.904842     1.370552     1.411092        0.00002            0.1
# ..           ...          ...          ...            ...            ...
# 123     3.488218     2.976868     2.555468        0.00002            0.1
# 124     3.488387     2.977844     2.554847        0.00002            0.1
# 125     3.488548     2.978794     2.554236        0.00002            0.1
# 126     3.488700     2.979719     2.553634        0.00002            0.1
# 127     3.488843     2.980621     2.553042        0.00002            0.1
#
#          loss  n_exps  n_iters  stop_val  time_constant_pow_0  \
# ...

# %%
fs.exps_params_
# Out:
# array([[-0.99773905,  3.48884339],
#        [-2.28986468,  2.98062062],
#        [-3.50634004,  2.55304151]])

# %% [markdown]
# # Проверка прототипа модели на частотном скане из 5 экспоненциальных составляющих

# %%
fs = SklMultiExpFrequencyScan(n_exps=5, filling_pulse = f_pulse)

fs.exps_params_=[[-1.0, 3.50],
                 [-1.7, 3.25],
                 [-2.3, 3.00],
                 [-2.9, 2.75],
                 [-3.5, 2.50]]

X = np.linspace(0, 3.5, 200)
y = fs.predict(X) 
y += np.random.normal(loc=0, scale=0.2, size=y.shape[0])

plot_experimental_points(X, y)
plt.show()

# %%
n_exps = 5

fs = SklMultiExpFrequencyScan(filling_pulse = f_pulse,                           
                              n_exps=n_exps,
                              n_iters=200,
                              stop_val=10**-5,
                              verbose=True
                             )

fs.fit(X, y)
# Out:
# iteration # 0
# loss: 6.55325804252158
# exps_params:
# [[-1.68865024  0.27417447]
#  [-2.28674727  0.3559918 ]
#  [-3.04579992  0.34832853]
#  [-3.22476535 -0.32997968]
#  [-2.68842335  0.11116986]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 5
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 4.848766562117726
# exps_params:
# [[-1.69280665  0.68766538]
#  [-2.28282487  0.77320366]
#  [-3.02969074  0.69085764]
#  [-3.24370395 -0.02083102]
#  [-2.68539679  0.50071567]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 5
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 3.661807869745799
# exps_params:
# [[-1.69551625  1.04944294]
#  [-2.27059923  1.11921306]
#  [-3.00531248  0.97056129]
#  [-3.24464463  0.22809122]
#  [-2.6732326   0.8170191 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 5
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# ...

# %%
plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.savefig('../plots/multiexp_test.pdf', bbox_inches='tight')
plt.show()

# %%
fit_results = fs.fit_results_
fit_results
# Out:
#      amplitude_0  amplitude_1  amplitude_2  amplitude_3  amplitude_4  \
# 0       0.274174     0.355992     0.348329    -0.329980     0.111170
# 1       0.687665     0.773204     0.690858    -0.020831     0.500716
# 2       1.049443     1.119213     0.970561     0.228091     0.817019
# 3       1.366198     1.405863     1.199624     0.431888     1.073635
# 4       1.643427     1.643343     1.387384     0.600976     1.281560
# ..           ...          ...          ...          ...          ...
# 109     3.902204     3.464553     2.725208     2.080872     2.797550
# 110     3.901865     3.464991     2.725435     2.081581     2.798072
# 111     3.901519     3.465425     2.725658     2.082278     2.798585
# 112     3.901165     3.465854     2.725877     2.082962     2.799088
# 113     3.900804     3.466281     2.726093     2.083634     2.799582
#
#      filling_pulse  learning_rate       loss  n_exps  n_iters  stop_val  \
# ...

# %%
fs.exps_params_
# Out:
# array([[-1.03619825,  3.90080414],
#        [-1.81952455,  3.46628056],
#        [-3.02388188,  2.72609329],
#        [-3.53045488,  2.08363411],
#        [-2.38622714,  2.79958183]])

# %% [markdown]
# # Пример неудачной идентификации - недостаточное количество экспоененциальных составляющих

# %%
plot_experimental_points(X, y)
plt.show()

# %%
n_exps = 3

fs = SklMultiExpFrequencyScan(filling_pulse = f_pulse,                           
                              n_exps=n_exps,
                              n_iters=200,
                              learning_rate=0.075,
                              stop_val=10**-5,
                              verbose=True
                             )

fs.fit(X, y)

plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.show()
# Out:
# iteration # 0
# loss: 29.414285783048385
# exps_params:
# [[-2.15719711 -0.12943934]
#  [-2.92962211 -0.03396346]
#  [-1.0793913  -0.00439995]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.075
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 25.787689708523303
# exps_params:
# [[-2.15919417  0.22178688]
#  [-2.93447748  0.25943452]
#  [-1.07864222  0.26383168]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.075
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 22.55320008114546
# exps_params:
# [[-2.15531145  0.54923015]
#  [-2.90062839  0.53277807]
#  [-1.1207694   0.51578243]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.075
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 19.587509902414755
# exps_params:
# [[-2.14540175  0.8535133 ]
#  [-2.84117076  0.79160227]
#  [-1.19386959  0.75854201]]
# ...

# %%
fit_results = fs.fit_results_
fit_results
# Out:
#      amplitude_0  amplitude_1  amplitude_2  filling_pulse  learning_rate  \
# 0      -0.129439    -0.033963    -0.004400        0.00002          0.075
# 1       0.221787     0.259435     0.263832        0.00002          0.075
# 2       0.549230     0.532778     0.515782        0.00002          0.075
# 3       0.853513     0.791602     0.758542        0.00002          0.075
# 4       1.133797     1.037933     0.994794        0.00002          0.075
# ..           ...          ...          ...            ...            ...
# 157     5.161231     4.726263     4.780585        0.00002          0.075
# 158     5.162906     4.725297     4.780372        0.00002          0.075
# 159     5.164574     4.724173     4.780324        0.00002          0.075
# 160     5.166211     4.723282     4.780040        0.00002          0.075
# 161     5.167850     4.722078     4.780081        0.00002          0.075
#
#           loss  n_exps  n_iters  stop_val  time_constant_pow_0  \
# ...

# %%
fs.exps_params_
# Out:
# array([[-2.13949832,  5.16785036],
#        [-3.18980595,  4.72207808],
#        [-1.13851022,  4.78008118]])

# %% [markdown]
# # Пример неудачной идентификации - избыточное количество экспоененциальных составляющих (7 вместо 5)

# %%
plot_experimental_points(X, y)
plt.show()

# %%
n_exps = 7

fs = SklMultiExpFrequencyScan(filling_pulse = f_pulse,                           
                              n_exps=n_exps,
                              n_iters=200,
                              stop_val=10**-5,
                              verbose=True
                             )

fs.fit(X, y)

plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.show()
# Out:
# iteration # 0
# loss: 28.944107016901242
# exps_params:
# [[-2.70741013e+00 -3.61502387e-02]
#  [-2.17700568e+00  9.65254699e-02]
#  [-1.60796258e+00 -1.11737236e-01]
#  [-3.35886082e+00 -7.46529415e-02]
#  [-2.45226020e+00  8.03519312e-02]
#  [-2.81148541e+00 -6.13988940e-04]
#  [-1.71882732e+00 -4.79522238e-02]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 7
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 18.056033618010407
# exps_params:
# [[-2.7121846   0.3832845 ]
#  [-2.17409306  0.55686149]
#  [-1.59750885  0.33144693]
#  [-3.3796962   0.21761442]
#  [-2.44566798  0.5258867 ]
#  [-2.81158021  0.4045649 ]
#  [-1.71561549  0.40417991]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 7
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 11.65000128501252
# exps_params:
# [[-2.6790177   0.69511846]
#  [-2.14911713  0.902078  ]
#  [-1.60756037  0.68363592]
# ...

# %%
fit_results = fs.fit_results_
fit_results
# Out:
#      amplitude_0  amplitude_1  amplitude_2  amplitude_3  amplitude_4  \
# 0      -0.036150     0.096525    -0.111737    -0.074653     0.080352
# 1       0.383285     0.556861     0.331447     0.217614     0.525887
# 2       0.695118     0.902078     0.683636     0.442390     0.856723
# 3       0.927689     1.157514     0.962823     0.628880     1.099922
# 4       1.100812     1.345207     1.182403     0.787717     1.276963
# ..           ...          ...          ...          ...          ...
# 99      2.041746     2.356666     2.245791     1.861361     2.245489
# 100     2.041889     2.356788     2.245968     1.861533     2.245631
# 101     2.042025     2.356906     2.246139     1.861695     2.245770
# 102     2.042153     2.357020     2.246305     1.861848     2.245905
# 103     2.042274     2.357129     2.246467     1.861991     2.246036
#
#      amplitude_5  amplitude_6  filling_pulse  learning_rate       loss  ...  \
# ...

# %%
fs.exps_params_
# Out:
# array([[-2.71223945,  2.04227406],
#        [-1.84160211,  2.35712947],
#        [-0.88207362,  2.24646716],
#        [-3.58990554,  1.86199094],
#        [-2.18927036,  2.24603605],
#        [-3.0848616 ,  2.06700655],
#        [-1.30292811,  2.28837225]])

# %% [markdown]
# # Пример неудачной идентификации - избыточное количество экспоененциальных составляющих (30 вместо 5)

# %%
plot_experimental_points(X, y)
plt.show()

# %%
n_exps = 30

fs = SklMultiExpFrequencyScan(filling_pulse = f_pulse,                           
                              n_exps=n_exps,
                              n_iters=200,
                              stop_val=10**-5,
                              verbose=True
                             )

fs.fit(X, y)

plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.show()
# Out:
# iteration # 0
# loss: 28.70956247079099
# exps_params:
# [[-1.69709798e+00 -5.45786143e-03]
#  [-1.05461452e+00 -2.22498279e-02]
#  [-3.10864503e+00 -1.95574356e-02]
#  [-3.35852717e+00  2.80925787e-02]
#  [-3.39440604e+00 -3.24181234e-02]
#  [-3.28509456e+00  2.84484973e-02]
#  [-1.39338982e+00  2.54796988e-02]
#  [-2.26918096e+00 -1.91371668e-02]
#  [-1.49073238e+00  2.39666516e-02]
#  [-2.24365671e+00 -1.69833916e-02]
#  [-2.24410888e+00  2.04183319e-02]
#  [-1.29495556e+00 -2.80872446e-02]
#  [-1.94217224e+00  7.44148741e-03]
#  [-2.85801230e+00  1.42655002e-02]
#  [-2.12166178e+00  2.50201001e-02]
#  [-1.58162509e+00  1.51736553e-02]
#  [-2.37225279e+00 -2.79267646e-02]
#  [-2.07669935e+00  1.65829833e-04]
#  [-2.01838878e+00 -1.09848514e-02]
#  [-1.42260395e+00 -2.22046982e-02]
#  [-1.47540914e+00 -1.29767992e-02]
#  [-2.99142794e+00 -1.71385183e-02]
#  [-2.17876188e+00  4.38243934e-03]
#  [-2.22259070e+00 -7.49629759e-03]
#  [-2.04413700e+00 -9.77638218e-03]
# ...

# %%
fit_results = fs.fit_results_
fit_results
# Out:
#      amplitude_0  amplitude_1  amplitude_10  amplitude_11  amplitude_12  \
# 0      -0.005458    -0.022250      0.020418     -0.028087      0.007441
# 1       0.443825     0.328727      0.479193      0.371218      0.468874
# 2       0.465752     0.422317      0.465865      0.443653      0.466513
# 3       0.479895     0.492276      0.450432      0.497253      0.459895
# 4       0.491947     0.545445      0.439795      0.538653      0.455659
# ..           ...          ...           ...           ...           ...
# 192     0.552453     0.742543      0.416464      0.651031      0.492552
# 193     0.552508     0.742580      0.416412      0.651049      0.492610
# 194     0.552563     0.742616      0.416361      0.651067      0.492667
# 195     0.552618     0.742651      0.416311      0.651084      0.492724
# 196     0.552671     0.742686      0.416261      0.651102      0.492780
#
#      amplitude_13  amplitude_14  amplitude_15  amplitude_16  amplitude_17  \
# ...

# %%
fs.exps_params_
# Out:
# array([[-1.57210519,  0.55267113],
#        [-0.70007823,  0.7426858 ],
#        [-3.14779354,  0.47771362],
#        [-3.5689423 ,  0.52534459],
#        [-3.60603556,  0.47254504],
#        [-3.44421651,  0.51430775],
#        [-1.02295234,  0.65888894],
#        [-2.31522415,  0.37881207],
#        [-1.25749757,  0.61694663],
#        [-2.26637239,  0.37890564],
#        [-2.26684071,  0.41626057],
#        [-0.90017439,  0.65110163],
#        [-1.77621903,  0.49278042],
#        [-2.91444884,  0.53566606],
#        [-2.02150224,  0.44035647],
#        [-1.43810094,  0.59240515],
#        [-2.49272768,  0.39433155],
#        [-1.95228672,  0.43080047],
#        [-1.87064871,  0.44269812],
#        [-1.1373219 ,  0.59235256],
#        [-1.25199027,  0.5838674 ],
#        [-3.01775026,  0.49694076],
#        [-2.13640156,  0.40460261],
#        [-2.22479248,  0.38823617],
#        [-1.90599915,  0.43337466],
#        [-2.78772799,  0.52764176],
#        [-2.57005127,  0.41505315],
# ...
