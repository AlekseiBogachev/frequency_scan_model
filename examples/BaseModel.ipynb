# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from pydlts.fsmodels import SklMultiExpFrequencyScan
from pydlts.fsmodels import SklSingleExpFrequencyScan

from pydlts.fsplots import plot_model
from pydlts.fsplots import plot_loss_path
from pydlts.fsplots import plot_experimental_points

# %matplotlib inline

# %% [markdown]
# # Single exponential model class

# %%
fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6)
fs
# Out:
# SklSingleExpFrequencyScan()

# %%
fs.get_params()
# Out:
# {'filling_pulse': 1.9999999999999998e-05,
#  'fit_p_coef': True,
#  'learning_rate': 0.1,
#  'n_iters': 1000,
#  'stop_val': None,
#  'verbose': False}

# %%
X = np.linspace(0, 3.5, 100)
fs.exps_params_ = [[-2.5, 3.5]]
fs.p_coef_ = 0.3

# %%
y = fs.predict(X)

plot_experimental_points(X, y)
plt.show()

# %%
fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6,
                               fit_p_coef = True,
                               learning_rate = 0.1,
                               n_iters = 200, 
                               stop_val = 10**-5,
                               verbose = True)

fs.fit(X, y)
# Out:
# iteration # 0
# loss: 6.373554277519502
# exps_params:
# [[-1.73277542 -0.44362014]]
# p_coef: 1.0
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 5.970849274787668
# exps_params:
# [[-1.6807842  -0.24681847]]
# p_coef: 1.0434380550234896
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 5.663371536246126
# exps_params:
# [[-1.65086425 -0.07038267]]
# p_coef: 1.0655029261396665
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 5.4084701481472255
# exps_params:
# [[-1.64219819  0.09172146]]
# p_coef: 1.0714328422538315
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 4
# loss: 5.176421770346125
# exps_params:
# [[-1.65353881  0.24431988]]
# p_coef: 1.0639616489388108
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 5
# loss: 4.944804549749438
# exps_params:
# [[-1.68359392  0.39142702]]
# p_coef: 1.0443006600203069
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 6
# loss: 4.695517889209435
# exps_params:
# [[-1.73099766  0.5364547 ]]
# p_coef: 1.0125958418666954
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 7
# loss: 4.413558001236084
# exps_params:
# [[-1.79400907  0.68229617]]
# p_coef: 0.9681539331225391
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 8
# loss: 4.087161482019202
# exps_params:
# [[-1.87003421  0.83129206]]
# p_coef: 0.909554647790352
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 9
# loss: 3.7085917818414087
# exps_params:
# [[-1.95510565  0.98509173]]
# p_coef: 0.8347020403883079
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 10
# loss: 3.2739595933616554
# exps_params:
# [[-2.04357535  1.14446603]]
# p_coef: 0.7408340817131551
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 11
# loss: 2.780127176296357
# exps_params:
# [[-2.12837894  1.30917117]]
# p_coef: 0.6245128792900948
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 12
# loss: 2.2199545797941926
# exps_params:
# [[-2.20212306  1.47789284]]
# p_coef: 0.48181757328062214
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 13
# loss: 1.5938035782540454
# exps_params:
# [[-2.25910776  1.64783232]]
# p_coef: 0.31029590544371277
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 14
# loss: 1.0600740673727223
# exps_params:
# [[-2.29999389  1.81168214]]
# p_coef: 0.12382849950833005
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 15
# loss: 0.8976164061087124
# exps_params:
# [[-2.34607632  1.94154785]]
# p_coef: 0.090403992464198
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 16
# loss: 0.810305190258461
# exps_params:
# [[-2.39753062  2.04444378]]
# p_coef: 0.2115959015573622
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 17
# loss: 0.6948795910804327
# exps_params:
# [[-2.41762234  2.16775207]]
# p_coef: 0.07622036214157465
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 18
# loss: 0.8960401065406959
# exps_params:
# [[-2.47823111  2.2351437 ]]
# p_coef: 0.39563435158642246
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 19
# loss: 0.46430135955217666
# exps_params:
# [[-2.45425228  2.3533999 ]]
# p_coef: 0.20841630845938938
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 20
# loss: 0.40780109401913833
# exps_params:
# [[-2.46785246  2.44531984]]
# p_coef: 0.11115691039467404
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 21
# loss: 0.4887603665938701
# exps_params:
# [[-2.52325707  2.49770196]]
# p_coef: 0.3168123298644919
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 22
# loss: 0.26994943227415064
# exps_params:
# [[-2.49012275  2.5902063 ]]
# p_coef: 0.14877587547086202
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 23
# loss: 0.2515629083013671
# exps_params:
# [[-2.52719471  2.6418141 ]]
# p_coef: 0.2292276914770338
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 24
# loss: 0.2242225479408201
# exps_params:
# [[-2.51723277  2.70994531]]
# p_coef: 0.1353115465187429
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 25
# loss: 0.2813922075978042
# exps_params:
# [[-2.5617416  2.7435317]]
# p_coef: 0.30244645125035224
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 26
# loss: 0.16230072469572498
# exps_params:
# [[-2.51743105  2.81311118]]
# p_coef: 0.1557403899410473
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 27
# loss: 0.1810423803439255
# exps_params:
# [[-2.55412633  2.84284125]]
# p_coef: 0.27633337666300106
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 28
# loss: 0.131536450827793
# exps_params:
# [[-2.52164493  2.899889  ]]
# p_coef: 0.16111855922032076
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 29
# loss: 0.15665640296913216
# exps_params:
# [[-2.55819795  2.92197281]]
# p_coef: 0.29133829877444295
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 30
# loss: 0.10001739788970716
# exps_params:
# [[-2.52049038  2.97402854]]
# p_coef: 0.17520381506662053
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 31
# loss: 0.11170570176553742
# exps_params:
# [[-2.55219562  2.99291632]]
# p_coef: 0.2831554679004957
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 32
# loss: 0.07769269211936637
# exps_params:
# [[-2.52088755  3.03714515]]
# p_coef: 0.18635031371032212
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 33
# loss: 0.08345801041617314
# exps_params:
# [[-2.54864555  3.05300485]]
# p_coef: 0.2804291711054552
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 34
# loss: 0.06001609557228936
# exps_params:
# [[-2.52099604  3.09117537]]
# p_coef: 0.19748493995766236
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 35
# loss: 0.06150553700661629
# exps_params:
# [[-2.54457667  3.10491413]]
# p_coef: 0.277097480097143
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 36
# loss: 0.046081166112885256
# exps_params:
# [[-2.52106013  3.13759648]]
# p_coef: 0.2083724907314754
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 37
# loss: 0.04502818516474967
# exps_params:
# [[-2.54041607  3.14986645]]
# p_coef: 0.2738645001564665
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 38
# loss: 0.03516531599345465
# exps_params:
# [[-2.52105664  3.17765243]]
# p_coef: 0.21893611789601372
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 39
# loss: 0.03293809747501543
# exps_params:
# [[-2.53628131  3.18893588]]
# p_coef: 0.2710470926354548
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 40
# loss: 0.026738513439225085
# exps_params:
# [[-2.52090598  3.21239696]]
# p_coef: 0.2290489177414997
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 41
# loss: 0.02426690578810507
# exps_params:
# [[-2.53225355  3.22302352]]
# p_coef: 0.26891152840225657
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 42
# loss: 0.020366546838595064
# exps_params:
# [[-2.52051868  3.24272522]]
# p_coef: 0.23851115587618696
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 43
# loss: 0.01815783510590309
# exps_params:
# [[-2.52841757  3.25288148]]
# p_coef: 0.26766474131040485
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 44
# loss: 0.01564246648558372
# exps_params:
# [[-2.5198286   3.26938932]]
# p_coef: 0.24708283618560703
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 45
# loss: 0.01387076318727487
# exps_params:
# [[-2.52486241  3.27913607]]
# p_coef: 0.26740469402205563
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 46
# loss: 0.012170692046737642
# exps_params:
# [[-2.5188215  3.2930028]]
# p_coef: 0.25455947772556053
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 47
# loss: 0.010813226579983298
# exps_params:
# [[-2.52166389  3.30230839]]
# p_coef: 0.26808542385495115
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 48
# loss: 0.00959718925274918
# exps_params:
# [[-2.51754637  3.3140457 ]]
# p_coef: 0.2608525555930071
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 49
# loss: 0.00856124868841427
# exps_params:
# [[-2.51886399  3.32283219]]
# p_coef: 0.26953017512786237
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 50
# loss: 0.0076466877290302104
# exps_params:
# [[-2.51609961  3.33288046]]
# p_coef: 0.2660205374485945
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 51
# loss: 0.006843570922121691
# exps_params:
# [[-2.5164617   3.34106872]]
# p_coef: 0.27149098647577924
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 52
# loss: 0.0061317520186954175
# exps_params:
# [[-2.51459104  3.34977983]]
# p_coef: 0.27023181645857947
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 53
# loss: 0.005498379865701947
# exps_params:
# [[-2.51442092  3.35731878]]
# p_coef: 0.27372038975235014
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 54
# loss: 0.004933751991950368
# exps_params:
# [[-2.51311287  3.36495731]]
# p_coef: 0.2736937727819424
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 55
# loss: 0.004428648264977528
# exps_params:
# [[-2.51268794  3.37183287]]
# p_coef: 0.27602060340516943
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 56
# loss: 0.003976741439885125
# exps_params:
# [[-2.51172543  3.37859087]]
# p_coef: 0.2765947275337286
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 57
# loss: 0.0035716270626960293
# exps_params:
# [[-2.51120757  3.38482038]]
# p_coef: 0.2782595822249945
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 58
# loss: 0.0032085154299314844
# exps_params:
# [[-2.5104587   3.39083663]]
# p_coef: 0.2790784242390893
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 59
# loss: 0.002882717525335401
# exps_params:
# [[-2.50993221  3.39645787]]
# p_coef: 0.2803634662029408
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 60
# loss: 0.002590423242874372
# exps_params:
# [[-2.50932096  3.40183511]]
# p_coef: 0.28124395007285435
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 61
# loss: 0.0023280424217808015
# exps_params:
# [[-2.50882434  3.40689595]]
# p_coef: 0.28229979091208557
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 62
# loss: 0.0020925100333084178
# exps_params:
# [[-2.50830797  3.41171363]]
# p_coef: 0.28315657549715034
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 63
# loss: 0.0018810090592279866
# exps_params:
# [[-2.5078554   3.41626483]]
# p_coef: 0.2840612191427799
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 64
# loss: 0.0016910726966395645
# exps_params:
# [[-2.50740954  3.42058728]]
# p_coef: 0.2848595453196989
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 65
# loss: 0.0015204641723056973
# exps_params:
# [[-2.50700359  3.42467832]]
# p_coef: 0.2856536501122094
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 66
# loss: 0.0013672003683727757
# exps_params:
# [[-2.50661361  3.42855971]]
# p_coef: 0.2863829207800347
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 67
# loss: 0.001229494790028239
# exps_params:
# [[-2.50625188  3.43223672]]
# p_coef: 0.28708888553785095
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 68
# loss: 0.0011057540111935585
# exps_params:
# [[-2.50590824  3.4357239 ]]
# p_coef: 0.2877491202918805
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 69
# loss: 0.0009945466156987082
# exps_params:
# [[-2.50558662  3.43902903]]
# p_coef: 0.28838064787353973
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 70
# loss: 0.0008945920941865903
# exps_params:
# [[-2.50528246  3.44216314]]
# p_coef: 0.28897603948553513
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 71
# loss: 0.0008047412792714312
# exps_params:
# [[-2.50499655  3.44513442]]
# p_coef: 0.28954265232000526
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 72
# loss: 0.0007239645567106781
# exps_params:
# [[-2.50472658  3.44795197]]
# p_coef: 0.29007870437783595
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 73
# loss: 0.000651338088078329
# exps_params:
# [[-2.50447223  3.45062356]]
# p_coef: 0.29058778859577433
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 74
# loss: 0.0005860333993350017
# exps_params:
# [[-2.50423212  3.45315705]]
# p_coef: 0.29107013238207446
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 75
# loss: 0.0005273070123430518
# exps_params:
# [[-2.50400562  3.45555958]]
# p_coef: 0.2915278451181018
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 76
# loss: 0.00047449179750096176
# exps_params:
# [[-2.50379175  3.45783807]]
# p_coef: 0.2919617962077765
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 77
# loss: 0.0004269889017744796
# exps_params:
# [[-2.50358984  3.45999897]]
# p_coef: 0.2923734745337218
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 78
# loss: 0.00038426072916560266
# exps_params:
# [[-2.5033991   3.46204845]]
# p_coef: 0.29276389674311826
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 79
# loss: 0.0003458245549548832
# exps_params:
# [[-2.50321891  3.46399231]]
# p_coef: 0.2931342552026829
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 80
# loss: 0.0003112468748643332
# exps_params:
# [[-2.50304862  3.46583605]]
# p_coef: 0.2934855443335697
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 81
# loss: 0.0002801383148519694
# exps_params:
# [[-2.50288766  3.46758489]]
# p_coef: 0.29381878382751125
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 82
# loss: 0.00025214909370504775
# exps_params:
# [[-2.50273549  3.46924377]]
# p_coef: 0.294134893987941
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 83
# loss: 0.0002269649500169336
# exps_params:
# [[-2.50259159  3.47081734]]
# p_coef: 0.29443477256778705
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 84
# loss: 0.0002043034998903794
# exps_params:
# [[-2.50245549  3.47231005]]
# p_coef: 0.2947192548575477
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 85
# loss: 0.0001839109706796069
# exps_params:
# [[-2.50232675  3.47372608]]
# p_coef: 0.2949891407663083
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 86
# loss: 0.00016555927563755132
# exps_params:
# [[-2.50220494  3.4750694 ]]
# p_coef: 0.2952451831915428
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 87
# loss: 0.00014904339076088628
# exps_params:
# [[-2.50208967  3.47634378]]
# p_coef: 0.295488098321655
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 88
# loss: 0.00013417900336419098
# exps_params:
# [[-2.50198058  3.47755277]]
# p_coef: 0.29571856320763446
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 89
# loss: 0.0001208004030211398
# exps_params:
# [[-2.50187731  3.47869977]]
# p_coef: 0.2959372203830686
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 90
# loss: 0.00010875858985973517
# exps_params:
# [[-2.50177955  3.47978796]]
# p_coef: 0.29614467829749597
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 91
# loss: 9.791957724344689e-05
# exps_params:
# [[-2.50168699  3.48082039]]
# p_coef: 0.29634151394733915
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 92
# loss: 8.81628686711897e-05
# exps_params:
# [[-2.50159934  3.48179992]]
# p_coef: 0.2965282741029863
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# SklSingleExpFrequencyScan(n_iters=200, stop_val=1e-05, verbose=True)

# %%
fs.print_all_params()
# Out:
# exps_params:
# [[-2.50159934  3.48179992]]
# p_coef: 0.2965282741029863
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True

# %%
fs.fit_results_
# Out:
#     amplitude_0  filling_pulse  fit_p_coef  learning_rate      loss  n_exps  \
# 0     -0.443620        0.00002        True            0.1  6.373554       1
# 1     -0.246818        0.00002        True            0.1  5.970849       1
# 2     -0.070383        0.00002        True            0.1  5.663372       1
# 3      0.091721        0.00002        True            0.1  5.408470       1
# 4      0.244320        0.00002        True            0.1  5.176422       1
# ..          ...            ...         ...            ...       ...     ...
# 88     3.477553        0.00002        True            0.1  0.000134       1
# 89     3.478700        0.00002        True            0.1  0.000121       1
# 90     3.479788        0.00002        True            0.1  0.000109       1
# 91     3.480820        0.00002        True            0.1  0.000098       1
# 92     3.481800        0.00002        True            0.1  0.000088       1
#
#     n_iters    p_coef  stop_val  time_constant_pow_0  verbose
# 0       200  1.000000   0.00001            -1.732775     True
# 1       200  1.043438   0.00001            -1.680784     True
# 2       200  1.065503   0.00001            -1.650864     True
# 3       200  1.071433   0.00001            -1.642198     True
# 4       200  1.063962   0.00001            -1.653539     True
# ..      ...       ...       ...                  ...      ...
# 88      200  0.295719   0.00001            -2.501981     True
# 89      200  0.295937   0.00001            -2.501877     True
# 90      200  0.296145   0.00001            -2.501780     True
# 91      200  0.296342   0.00001            -2.501687     True
# 92      200  0.296528   0.00001            -2.501599     True
#
# [93 rows x 11 columns]

# %%
plot_loss_path(fs.fit_results_)
plt.show()

# %%
y_pred = fs.predict(X)

plot_model(X, y, SklSingleExpFrequencyScan, fs.fit_results_)
plt.show()

# %%
mean_squared_error(y, y_pred, squared=False)
# Out:
# 0.00938950843607852

# %%
def display_scores(scores):
    print(f'Scores: {scores}')
    print(f'Mean: {scores.mean()}')
    print(f'Standard deviation: {scores.std()}')

# %%
fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6,
                               fit_p_coef = True,
                               learning_rate = 0.1,
                               n_iters = 200, 
                               stop_val = 10**-5,
                               verbose = False)

scores = cross_val_score(fs, X, y, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
display_scores(np.sqrt(-scores))
# Out:
# Scores: [0.00371999 0.00666219 0.02345179 0.05793482 0.00832607]
# Mean: 0.02001896918502784
# Standard deviation: 0.020150335967387457

# %%
fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6,
                               fit_p_coef = True,
                               learning_rate = 0.1,
                               n_iters = 200, 
                               stop_val = 10**-5,
                               verbose = False)

grid_search = GridSearchCV(fs, {'fit_p_coef': [False, True]}, cv=5, scoring='neg_mean_squared_error',
                           return_train_score=True, n_jobs=-1)

# %%
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=SklSingleExpFrequencyScan(n_iters=200, stop_val=1e-05),
#              n_jobs=-1, param_grid={'fit_p_coef': [False, True]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 1.2909820808577324 {'fit_p_coef': False}
# 0.017753579898971895 {'fit_p_coef': True}

# %% [markdown]
# # Multi exponential model class

# %%
fs = SklMultiExpFrequencyScan(filling_pulse = 20*10**-6,
                              n_exps = 3,
                              learning_rate = 0.1,
                              n_iters = 1000, 
                              stop_val = 10**-5,
                              verbose = True)

fs.exps_params_ = [[-1.0, 3.5],
                   [-2.3, 3.0],
                   [-3.5, 2.5]]

# %%
y = fs.predict(X)

# %%
plot_experimental_points(X, y)
plt.show()

# %%
fs.fit(X, y)
# Out:
# iteration # 0
# loss: 8.410694365279847
# exps_params:
# [[-3.35436209  0.2185318 ]
#  [-1.45405159 -0.0484734 ]
#  [-3.31536846  0.30805388]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 7.454883114682409
# exps_params:
# [[-3.32966818  0.35992276]
#  [-1.45382002  0.18729196]
#  [-3.28156571  0.45347527]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 6.599352462532519
# exps_params:
# [[-3.29237117  0.49011587]
#  [-1.45419414  0.40974709]
#  [-3.23575405  0.58825698]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 5.830536808538179
# exps_params:
# [[-3.24663209  0.61075261]
#  [-1.45369166  0.61936481]
#  [-3.18167791  0.71380501]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 4
# loss: 5.1417183723964035
# exps_params:
# [[-3.19614383  0.72277704]
#  [-1.45065504  0.81651171]
#  [-3.12247572  0.830889  ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 5
# loss: 4.528731167849562
# exps_params:
# [[-3.14404599  0.82671612]
#  [-1.44337973  1.00150628]
#  [-3.06063864  0.93992577]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 6
# loss: 3.9873179792397746
# exps_params:
# [[-3.09291051  0.92290226]
#  [-1.43037345  1.17468188]
#  [-2.9980266   1.0411921 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 7
# loss: 3.511991130387528
# exps_params:
# [[-3.04477823  1.01163309]
#  [-1.41070755  1.33644407]
#  [-2.93591156  1.13496944]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 8
# loss: 3.09615914938602
# exps_params:
# [[-3.00122915  1.09326845]
#  [-1.38436829  1.487301  ]
#  [-2.87502835  1.2216266 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 9
# loss: 2.7330212199761967
# exps_params:
# [[-2.96348185  1.16826812]
#  [-1.35246342  1.62784863]
#  [-2.81563852  1.30164559]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 10
# loss: 2.416438159259
# exps_params:
# [[-2.93252419  1.23718194]
#  [-1.31712897  1.75871282]
#  [-2.75762815  1.37560052]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 11
# loss: 2.1410755848151752
# exps_params:
# [[-2.90925794  1.300617  ]
#  [-1.28105981  1.88047906]
#  [-2.70064927  1.44411025]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 12
# loss: 1.901788831638455
# exps_params:
# [[-2.89460371  1.35921392]
#  [-1.24678003  1.99365131]
#  [-2.64428818  1.50779555]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 13
# loss: 1.6929482958883932
# exps_params:
# [[-2.8894891   1.41365566]
#  [-1.21598422  2.09865811]
#  [-2.58823418  1.56726712]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 14
# loss: 1.5084309705155439
# exps_params:
# [[-2.89465914  1.4647054 ]
#  [-1.18929089  2.19588579]
#  [-2.5324491   1.62314932]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 15
# loss: 1.3424502980023463
# exps_params:
# [[-2.91030729  1.51323815]
#  [-1.16646435  2.28570598]
#  [-2.47737025  1.67611402]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 16
# loss: 1.1908735977021516
# exps_params:
# [[-2.93562127  1.56021023]
#  [-1.14685637  2.36848595]
#  [-2.42413592  1.72687748]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 17
# loss: 1.052202170676238
# exps_params:
# [[-2.96847667  1.60652407]
#  [-1.12978974  2.44459598]
#  [-2.37466493  1.77612184]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 18
# loss: 0.9271577521198344
# exps_params:
# [[-3.00561256  1.6528104 ]
#  [-1.11477487  2.51443125]
#  [-2.33130766  1.82435513]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 19
# loss: 0.816836315956464
# exps_params:
# [[-3.04343419  1.69924851]
#  [-1.10157023  2.57844485]
#  [-2.2960268   1.87179623]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 20
# loss: 0.7210590999798977
# exps_params:
# [[-3.07905451  1.74556546]
#  [-1.09011542  2.63716375]
#  [-2.26959759  1.91837713]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 21
# loss: 0.6382615529841986
# exps_params:
# [[-3.1108982   1.79122103]
#  [-1.08039178  2.69116361]
#  [-2.25142869  1.96385749]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 22
# loss: 0.5663666365534756
# exps_params:
# [[-3.13861049  1.83563869]
#  [-1.07230663  2.7410142 ]
#  [-2.24002422  2.00795984]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 23
# loss: 0.5035017977232984
# exps_params:
# [[-3.16257902  1.87835605]
#  [-1.06566453  2.78722896]
#  [-2.23362224  2.05045579]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 24
# loss: 0.44821489711258083
# exps_params:
# [[-3.18346688  1.91907302]
#  [-1.06020777  2.8302399 ]
#  [-2.23063914  2.09119682]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 25
# loss: 0.3994103726089734
# exps_params:
# [[-3.20192826  1.95763706]
#  [-1.05567353  2.8703967 ]
#  [-2.22985116  2.1301119 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 26
# loss: 0.35623246870805986
# exps_params:
# [[-3.2184929   1.99400609]
#  [-1.05183355  2.90797921]
#  [-2.23040072  2.16719162]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 27
# loss: 0.3179801536376791
# exps_params:
# [[-3.23354983  2.0282112 ]
#  [-1.04850959  2.94321355]
#  [-2.23172635  2.20246959]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 28
# loss: 0.28405867358639186
# exps_params:
# [[-3.2473724   2.06032723]
#  [-1.04557213  2.9762866 ]
#  [-2.23347797  2.23600633]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 29
# loss: 0.2539535349678648
# exps_params:
# [[-3.2601518   2.09045229]
#  [-1.04293106  3.00735713]
#  [-2.23544481  2.26787704]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 30
# loss: 0.22721553208523296
# exps_params:
# [[-3.27202546  2.1186947 ]
#  [-1.04052501  3.03656367]
#  [-2.23750305  2.29816331]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 31
# loss: 0.2034508361996618
# exps_params:
# [[-3.28309699  2.14516512]
#  [-1.03831213  3.06402965]
#  [-2.23958115  2.32694808]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 32
# loss: 0.18231351994629277
# exps_params:
# [[-3.29344871  2.16997221]
#  [-1.03626335  3.08986688]
#  [-2.24163841  2.35431266]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 33
# loss: 0.16349943912347079
# exps_params:
# [[-3.30314909  2.19322031]
#  [-1.03435777  3.11417778]
#  [-2.24365211  2.38033531]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
# iteration # 34
# loss: 0.1467410196671099
# exps_params:
# [[-3.31225685  2.21500835]
#  [-1.03257974  3.1370569 ]
#  [-2.24561007  2.40509054]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 35
# loss: 0.1318027371648457
# exps_params:
# [[-3.32082338  2.23542947]
#  [-1.03091702  3.15859198]
#  [-2.24750625  2.42864887]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 36
# loss: 0.11847716933716343
# exps_params:
# [[-3.32889408  2.254571  ]
#  [-1.02935965  3.17886472]
#  [-2.24933828  2.45107686]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 37
# loss: 0.10658154067603093
# exps_params:
# [[-3.3365093   2.27251457]
#  [-1.02789923  3.1979514 ]
#  [-2.25110591  2.47243723]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 38
# loss: 0.09595469657001734
# exps_params:
# [[-3.34370501  2.28933646]
#  [-1.02652851  3.21592332]
#  [-2.25281015  2.49278902]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 39
# loss: 0.08645445424697316
# exps_params:
# [[-3.35051333  2.30510781]
#  [-1.02524104  3.23284727]
#  [-2.25445267  2.51218776]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 40
# loss: 0.07795528455792744
# exps_params:
# [[-3.35696299  2.31989502]
#  [-1.02403106  3.24878577]
#  [-2.25603553  2.53068571]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 41
# loss: 0.07034628390437735
# exps_params:
# [[-3.36307975  2.33376   ]
#  [-1.02289327  3.26379749]
#  [-2.25756091  2.54833196]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 42
# loss: 0.06352940021038314
# exps_params:
# [[-3.36888674  2.34676052]
#  [-1.02182285  3.27793741]
#  [-2.259031    2.56517268]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 43
# loss: 0.05741788100170419
# exps_params:
# [[-3.37440481  2.35895049]
#  [-1.02081532  3.29125713]
#  [-2.26044797  2.58125129]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 44
# loss: 0.05193491544982594
# exps_params:
# [[-3.37965279  2.37038022]
#  [-1.01986652  3.30380508]
#  [-2.26181388  2.59660858]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 45
# loss: 0.047012445677781706
# exps_params:
# [[-3.38464774  2.38109669]
#  [-1.01897258  3.31562671]
#  [-2.2631307   2.61128289]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 46
# loss: 0.04259012561730535
# exps_params:
# [[-3.38940516  2.3911438 ]
#  [-1.0181299   3.32676468]
#  [-2.26440029  2.6253103 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 47
# loss: 0.038614409134872844
# exps_params:
# [[-3.39393922  2.40056256]
#  [-1.01733511  3.33725906]
#  [-2.26562441  2.6387247 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 48
# loss: 0.03503774949226782
# exps_params:
# [[-3.39826285  2.40939133]
#  [-1.01658507  3.34714747]
#  [-2.26680472  2.65155799]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 49
# loss: 0.03181789785943251
# exps_params:
# [[-3.40238795  2.41766598]
#  [-1.01587684  3.35646525]
#  [-2.26794278  2.66384015]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 50
# loss: 0.02891728687552302
# exps_params:
# [[-3.40632547  2.42542007]
#  [-1.0152077   3.36524561]
#  [-2.26904009  2.67559942]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 51
# loss: 0.026302489061738113
# exps_params:
# [[-3.41008553  2.43268503]
#  [-1.01457509  3.37351973]
#  [-2.27009807  2.68686236]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 52
# loss: 0.023943740560028914
# exps_params:
# [[-3.41367749  2.43949029]
#  [-1.01397663  3.38131694]
#  [-2.27111808  2.69765397]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 53
# loss: 0.021814522003809983
# exps_params:
# [[-3.41711008  2.44586343]
#  [-1.01341011  3.38866478]
#  [-2.27210143  2.70799782]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 54
# loss: 0.019891189389255336
# exps_params:
# [[-3.4203914   2.45183028]
#  [-1.01287346  3.39558915]
#  [-2.27304937  2.7179161 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 55
# loss: 0.018152648738060113
# exps_params:
# [[-3.42352904  2.45741509]
#  [-1.01236476  3.40211442]
#  [-2.2739631   2.72742972]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 56
# loss: 0.016580069142066733
# exps_params:
# [[-3.4265301   2.4626406 ]
#  [-1.01188223  3.40826348]
#  [-2.27484378  2.73655841]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 57
# loss: 0.015156629473720292
# exps_params:
# [[-3.42940121  2.46752812]
#  [-1.01142419  3.41405789]
#  [-2.27569256  2.74532078]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 58
# loss: 0.013867294648208666
# exps_params:
# [[-3.43214865  2.47209769]
#  [-1.01098909  3.41951791]
#  [-2.27651051  2.75373438]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 59
# loss: 0.012698617845607654
# exps_params:
# [[-3.43477828  2.4763681 ]
#  [-1.01057551  3.42466262]
#  [-2.2772987   2.76181578]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 60
# loss: 0.011638565555481524
# exps_params:
# [[-3.43729566  2.48035703]
#  [-1.0101821   3.42950998]
#  [-2.27805816  2.76958065]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 61
# loss: 0.010676362700280263
# exps_params:
# [[-3.43970603  2.48408107]
#  [-1.00980761  3.43407689]
#  [-2.27878989  2.77704377]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 62
# loss: 0.009802355437464348
# exps_params:
# [[-3.44201434  2.48755582]
#  [-1.00945088  3.43837926]
#  [-2.27949484  2.78421914]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 63
# loss: 0.00900788953854082
# exps_params:
# [[-3.44422527  2.49079594]
#  [-1.00911084  3.44243208]
#  [-2.28017398  2.79111997]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 64
# loss: 0.008285202503136383
# exps_params:
# [[-3.44634327  2.49381523]
#  [-1.00878649  3.44624948]
#  [-2.28082821  2.79775878]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 65
# loss: 0.007627327793230057
# exps_params:
# [[-3.44837255  2.49662667]
#  [-1.00847689  3.44984475]
#  [-2.28145841  2.80414741]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 66
# loss: 0.007028009769736142
# exps_params:
# [[-3.4503171   2.49924246]
#  [-1.00818118  3.45323043]
#  [-2.28206546  2.81029709]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
# iteration # 67
# loss: 0.006481628086784655
# exps_params:
# [[-3.45218073  2.50167409]
#  [-1.00789854  3.45641833]
#  [-2.28265019  2.81621844]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 68
# loss: 0.005983130449204139
# exps_params:
# [[-3.45396705  2.50393239]
#  [-1.00762824  3.4594196 ]
#  [-2.28321341  2.82192154]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 69
# loss: 0.005527972770857698
# exps_params:
# [[-3.4556795   2.50602755]
#  [-1.00736956  3.46224474]
#  [-2.28375591  2.82741594]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 70
# loss: 0.0051120658865115055
# exps_params:
# [[-3.45732133  2.50796915]
#  [-1.00712185  3.46490363]
#  [-2.28427846  2.8327107 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 71
# loss: 0.004731728070938564
# exps_params:
# [[-3.45889567  2.50976625]
#  [-1.00688452  3.46740564]
#  [-2.28478179  2.83781442]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 72
# loss: 0.004383642707327416
# exps_params:
# [[-3.46040548  2.51142736]
#  [-1.00665698  3.46975956]
#  [-2.28526663  2.84273527]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 73
# loss: 0.004064820524622288
# exps_params:
# [[-3.4618536   2.5129605 ]
#  [-1.00643872  3.47197372]
#  [-2.28573366  2.84748102]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 74
# loss: 0.0037725658914262634
# exps_params:
# [[-3.46324271  2.51437325]
#  [-1.00622924  3.47405594]
#  [-2.28618356  2.85205903]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 75
# loss: 0.003504446713899301
# exps_params:
# [[-3.46457539  2.51567274]
#  [-1.00602807  3.47601364]
#  [-2.28661697  2.85647631]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 76
# loss: 0.0032582675375034654
# exps_params:
# [[-3.46585409  2.5168657 ]
#  [-1.00583479  3.47785381]
#  [-2.28703454  2.86073954]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 77
# loss: 0.0030320454986097044
# exps_params:
# [[-3.46708115  2.51795847]
#  [-1.005649    3.47958304]
#  [-2.28743685  2.86485504]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 78
# loss: 0.0028239888127608846
# exps_params:
# [[-3.46825881  2.51895705]
#  [-1.00547031  3.48120755]
#  [-2.2878245   2.86882887]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 79
# loss: 0.002632477521947168
# exps_params:
# [[-3.4693892   2.51986706]
#  [-1.00529838  3.48273323]
#  [-2.28819806  2.87266676]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 80
# loss: 0.0024560462549631794
# exps_params:
# [[-3.47047436  2.52069384]
#  [-1.00513287  3.48416564]
#  [-2.28855807  2.8763742 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 81
# loss: 0.0022933687826250074
# exps_params:
# [[-3.47151623  2.52144242]
#  [-1.00497348  3.48551001]
#  [-2.28890505  2.87995641]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 82
# loss: 0.0021432441742249776
# exps_params:
# [[-3.47251667  2.52211754]
#  [-1.00481992  3.4867713 ]
#  [-2.28923951  2.88341835]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 83
# loss: 0.0020045843832250192
# exps_params:
# [[-3.47347746  2.52272367]
#  [-1.0046719   3.48795418]
#  [-2.28956194  2.88676478]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 84
# loss: 0.0018764031094251235
# exps_params:
# [[-3.47440028  2.52326503]
#  [-1.00452919  3.48906309]
#  [-2.28987282  2.89000022]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 85
# loss: 0.0017578058016707132
# exps_params:
# [[-3.47528677  2.52374562]
#  [-1.00439152  3.4901022 ]
#  [-2.29017259  2.89312899]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 86
# loss: 0.0016479806802696798
# exps_params:
# [[-3.47613846  2.5241692 ]
#  [-1.00425869  3.49107545]
#  [-2.29046169  2.89615522]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 87
# loss: 0.0015461906714654796
# exps_params:
# [[-3.47695685  2.52453931]
#  [-1.00413047  3.49198658]
#  [-2.29074053  2.89908283]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 88
# loss: 0.001451766158140215
# exps_params:
# [[-3.47774334  2.52485932]
#  [-1.00400666  3.4928391 ]
#  [-2.29100953  2.9019156 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 89
# loss: 0.0013640984613191732
# exps_params:
# [[-3.47849928  2.52513239]
#  [-1.00388707  3.49363636]
#  [-2.29126907  2.90465711]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 90
# loss: 0.0012826339762867678
# exps_params:
# [[-3.47922597  2.5253615 ]
#  [-1.00377153  3.49438149]
#  [-2.29151953  2.90731081]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 91
# loss: 0.0012068688953928192
# exps_params:
# [[-3.47992463  2.52554948]
#  [-1.00365987  3.49507747]
#  [-2.29176125  2.90987998]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 92
# loss: 0.0011363444568265634
# exps_params:
# [[-3.48059646  2.525699  ]
#  [-1.00355192  3.49572711]
#  [-2.29199459  2.91236775]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 93
# loss: 0.001070642665223347
# exps_params:
# [[-3.48124258  2.52581255]
#  [-1.00344754  3.49633308]
#  [-2.29221988  2.91477715]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 94
# loss: 0.001009382435672183
# exps_params:
# [[-3.48186406  2.52589253]
#  [-1.00334657  3.49689788]
#  [-2.29243743  2.91711105]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 95
# loss: 0.0009522161178310246
# exps_params:
# [[-3.48246194  2.52594116]
#  [-1.00324889  3.49742388]
#  [-2.29264755  2.91937219]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 96
# loss: 0.0008988263614351005
# exps_params:
# [[-3.4830372   2.52596056]
#  [-1.00315437  3.49791334]
#  [-2.29285053  2.92156323]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 97
# loss: 0.0008489232885584177
# exps_params:
# [[-3.48359079  2.52595274]
#  [-1.00306288  3.49836837]
#  [-2.29304664  2.92368668]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 98
# loss: 0.0008022419415956806
# exps_params:
# [[-3.4841236   2.52591956]
#  [-1.0029743   3.49879097]
#  [-2.29323617  2.92574498]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 99
# loss: 0.0007585399791882763
# exps_params:
# [[-3.48463651  2.52586281]
#  [-1.00288854  3.49918305]
#  [-2.29341937  2.92774043]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
# iteration # 100
# loss: 0.0007175955951943816
# exps_params:
# [[-3.48513033  2.52578417]
#  [-1.00280547  3.4995464 ]
#  [-2.29359648  2.92967527]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 101
# loss: 0.0006792056383682299
# exps_params:
# [[-3.48560584  2.52568521]
#  [-1.00272501  3.4998827 ]
#  [-2.29376774  2.93155163]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 102
# loss: 0.0006431839127469744
# exps_params:
# [[-3.48606382  2.52556743]
#  [-1.00264705  3.50019356]
#  [-2.29393338  2.93337156]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 103
# loss: 0.0006093596407658991
# exps_params:
# [[-3.48650496  2.52543223]
#  [-1.00257151  3.50048049]
#  [-2.29409362  2.93513702]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 104
# loss: 0.000577576072984477
# exps_params:
# [[-3.48692997  2.52528094]
#  [-1.0024983   3.50074492]
#  [-2.29424867  2.93684989]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 105
# loss: 0.0005476892299461601
# exps_params:
# [[-3.48733951  2.52511482]
#  [-1.00242734  3.5009882 ]
#  [-2.29439873  2.93851199]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 106
# loss: 0.0005195667631529287
# exps_params:
# [[-3.48773419  2.52493504]
#  [-1.00235854  3.5012116 ]
#  [-2.29454398  2.94012504]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 107
# loss: 0.0004930869234782581
# exps_params:
# [[-3.48811464  2.52474271]
#  [-1.00229183  3.50141634]
#  [-2.29468462  2.94169073]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 108
# loss: 0.0004681376265038549
# exps_params:
# [[-3.48848142  2.52453888]
#  [-1.00222714  3.50160354]
#  [-2.29482082  2.94321065]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 109
# loss: 0.0004446156053273588
# exps_params:
# [[-3.48883508  2.52432454]
#  [-1.0021644   3.50177429]
#  [-2.29495275  2.94468634]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 110
# loss: 0.00042242564233933725
# exps_params:
# [[-3.48917615  2.52410061]
#  [-1.00210355  3.5019296 ]
#  [-2.29508057  2.94611928]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 111
# loss: 0.0004014798723267859
# exps_params:
# [[-3.48950515  2.52386797]
#  [-1.00204452  3.50207044]
#  [-2.29520443  2.94751089]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 112
# loss: 0.0003816971499945671
# exps_params:
# [[-3.48982254  2.52362745]
#  [-1.00198724  3.5021977 ]
#  [-2.2953245   2.94886255]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 113
# loss: 0.0003630024757256203
# exps_params:
# [[-3.4901288   2.52337981]
#  [-1.00193166  3.50231225]
#  [-2.29544089  2.95017556]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 114
# loss: 0.00034532647396941755
# exps_params:
# [[-3.49042437  2.52312578]
#  [-1.00187773  3.50241489]
#  [-2.29555377  2.9514512 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 115
# loss: 0.0003286049192367822
# exps_params:
# [[-3.49070966  2.52286605]
#  [-1.00182539  3.50250639]
#  [-2.29566324  2.95269068]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 116
# loss: 0.0003127783051544515
# exps_params:
# [[-3.4909851   2.52260127]
#  [-1.00177459  3.50258746]
#  [-2.29576945  2.95389517]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 117
# loss: 0.00029779145248821134
# exps_params:
# [[-3.49125105  2.52233203]
#  [-1.00172528  3.50265879]
#  [-2.29587251  2.9550658 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 118
# loss: 0.00028359315243867546
# exps_params:
# [[-3.4915079   2.52205891]
#  [-1.00167741  3.50272102]
#  [-2.29597253  2.95620365]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 119
# loss: 0.00027013584188294814
# exps_params:
# [[-3.491756    2.52178243]
#  [-1.00163093  3.50277475]
#  [-2.29606963  2.95730978]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 120
# loss: 0.00025737530755483344
# exps_params:
# [[-3.49199569  2.52150309]
#  [-1.00158581  3.50282055]
#  [-2.29616391  2.95838518]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 121
# loss: 0.0002452704164413135
# exps_params:
# [[-3.4922273   2.52122138]
#  [-1.00154199  3.50285896]
#  [-2.29625547  2.95943084]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 122
# loss: 0.00023378286995401232
# exps_params:
# [[-3.49245114  2.52093771]
#  [-1.00149944  3.50289049]
#  [-2.29634442  2.96044768]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 123
# loss: 0.00022287697965557948
# exps_params:
# [[-3.4926675   2.52065251]
#  [-1.00145812  3.50291562]
#  [-2.29643083  2.9614366 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 124
# loss: 0.00021251946253794207
# exps_params:
# [[-3.49287668  2.52036615]
#  [-1.00141799  3.50293479]
#  [-2.29651481  2.96239848]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 125
# loss: 0.00020267925405036995
# exps_params:
# [[-3.49307894  2.52007901]
#  [-1.001379    3.50294844]
#  [-2.29659643  2.96333415]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True
# SklMultiExpFrequencyScan(n_exps=3, stop_val=1e-05, verbose=True)

# %%
fs.print_all_params()
# Out:
# exps_params:
# [[-3.49307894  2.52007901]
#  [-1.001379    3.50294844]
#  [-2.29659643  2.96333415]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 1000
# stop_val: 1e-05
# verbose: True

# %%
fs.fit_results_
# Out:
#      amplitude_0  amplitude_1  amplitude_2  filling_pulse  learning_rate  \
# 0       0.218532    -0.048473     0.308054        0.00002            0.1
# 1       0.359923     0.187292     0.453475        0.00002            0.1
# 2       0.490116     0.409747     0.588257        0.00002            0.1
# 3       0.610753     0.619365     0.713805        0.00002            0.1
# 4       0.722777     0.816512     0.830889        0.00002            0.1
# ..           ...          ...          ...            ...            ...
# 121     2.521221     3.502859     2.959431        0.00002            0.1
# 122     2.520938     3.502890     2.960448        0.00002            0.1
# 123     2.520653     3.502916     2.961437        0.00002            0.1
# 124     2.520366     3.502935     2.962398        0.00002            0.1
# 125     2.520079     3.502948     2.963334        0.00002            0.1
#
#          loss  n_exps  n_iters  stop_val  time_constant_pow_0  \
# 0    8.410694       3     1000   0.00001            -3.354362
# 1    7.454883       3     1000   0.00001            -3.329668
# 2    6.599352       3     1000   0.00001            -3.292371
# 3    5.830537       3     1000   0.00001            -3.246632
# 4    5.141718       3     1000   0.00001            -3.196144
# ..        ...     ...      ...       ...                  ...
# 121  0.000245       3     1000   0.00001            -3.492227
# 122  0.000234       3     1000   0.00001            -3.492451
# 123  0.000223       3     1000   0.00001            -3.492667
# 124  0.000213       3     1000   0.00001            -3.492877
# 125  0.000203       3     1000   0.00001            -3.493079
#
#      time_constant_pow_1  time_constant_pow_2  verbose
# 0              -1.454052            -3.315368     True
# 1              -1.453820            -3.281566     True
# 2              -1.454194            -3.235754     True
# 3              -1.453692            -3.181678     True
# 4              -1.450655            -3.122476     True
# ..                   ...                  ...      ...
# 121            -1.001542            -2.296255     True
# 122            -1.001499            -2.296344     True
# 123            -1.001458            -2.296431     True
# 124            -1.001418            -2.296515     True
# 125            -1.001379            -2.296596     True
#
# [126 rows x 13 columns]

# %%
plot_loss_path(fs.fit_results_)
plt.show()

# %%
plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.legend(loc='lower left')
plt.show()

# %%
mean_squared_error(y, fs.predict(X), squared=False)
# Out:
# 0.014236546422864288

# %%
fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6,
                               fit_p_coef = True,
                               learning_rate = 0.1,
                               n_iters = 1000, 
                               stop_val = 10**-5,
                               verbose = False)

scores = cross_val_score(fs, X, y, scoring='neg_mean_squared_error', cv=5, n_jobs=-1)
display_scores(np.sqrt(-scores))
# Out:
# Scores: [2.4544318         nan        nan 2.98198975 2.83911354]
# Mean: nan
# Standard deviation: nan

# %%
fs = SklMultiExpFrequencyScan(filling_pulse = 20*10**-6,
                              n_exps = 3,
                              learning_rate = 0.1,
                              n_iters = 1000, 
                              stop_val = 10**-5,
                              verbose = False)

grid_search = GridSearchCV(fs, {'n_exps': [2, 3, 4, 5, 6]}, cv=5, scoring='neg_mean_squared_error',
                           return_train_score=True, n_jobs=-1)

# %%
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=SklMultiExpFrequencyScan(n_exps=3, stop_val=1e-05),
#              n_jobs=-1, param_grid={'n_exps': [2, 3, 4, 5, 6]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 1.954152342944161 {'n_exps': 2}
# 0.38589001040953574 {'n_exps': 3}
# 0.4573499089861175 {'n_exps': 4}
# 0.4029260141075535 {'n_exps': 5}
# 0.37870788211008916 {'n_exps': 6}

# %%
grid_search.best_estimator_.print_all_params()
# Out:
# exps_params:
# [[-2.28993097  1.48928464]
#  [-1.08010341  1.74787075]
#  [-0.92279698  1.78218385]
#  [-3.36211568  1.26219228]
#  [-3.61777074  1.3249266 ]
#  [-2.29671887  1.43453852]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 6
# n_iters: 1000
# stop_val: 1e-05
# verbose: False

# %%
grid_search.best_estimator_.fit_results_
# Out:
#     amplitude_0  amplitude_1  amplitude_2  amplitude_3  amplitude_4  \
# 0      0.161634     0.147580    -0.005247     0.011946    -0.109831
# 1      0.369089     0.369722     0.219300     0.207646     0.061473
# 2      0.530733     0.552679     0.411549     0.360459     0.198989
# 3      0.656305     0.703737     0.577023     0.479866     0.311125
# 4      0.753787     0.829463     0.720696     0.573393     0.403831
# ..          ...          ...          ...          ...          ...
# 82     1.486955     1.748394     1.782689     1.262958     1.325408
# 83     1.487570     1.748260     1.782560     1.262769     1.325296
# 84     1.488163     1.748128     1.782433     1.262579     1.325178
# 85     1.488734     1.747999     1.782307     1.262386     1.325055
# 86     1.489285     1.747871     1.782184     1.262192     1.324927
#
#     amplitude_5  filling_pulse  learning_rate      loss  n_exps  n_iters  \
# 0      0.110109        0.00002            0.1  8.371636       6     1000
# 1      0.317670        0.00002            0.1  6.081021       6     1000
# 2      0.479330        0.00002            0.1  4.581469       6     1000
# 3      0.604867        0.00002            0.1  3.578005       6     1000
# 4      0.702289        0.00002            0.1  2.877188       6     1000
# ..          ...            ...            ...       ...     ...      ...
# 82     1.432207        0.00002            0.1  0.000538       6     1000
# 83     1.432823        0.00002            0.1  0.000526       6     1000
# 84     1.433416        0.00002            0.1  0.000515       6     1000
# 85     1.433988        0.00002            0.1  0.000505       6     1000
# 86     1.434539        0.00002            0.1  0.000495       6     1000
#
#     stop_val  time_constant_pow_0  time_constant_pow_1  time_constant_pow_2  \
# 0    0.00001            -2.595603            -1.790970            -1.476953
# 1    0.00001            -2.588866            -1.789711            -1.476972
# 2    0.00001            -2.575963            -1.779463            -1.470822
# 3    0.00001            -2.560825            -1.756090            -1.451474
# 4    0.00001            -2.545723            -1.718906            -1.416673
# ..       ...                  ...                  ...                  ...
# 82   0.00001            -2.289416            -1.081050            -0.922187
# 83   0.00001            -2.289552            -1.080814            -0.922333
# 84   0.00001            -2.289683            -1.080577            -0.922483
# 85   0.00001            -2.289809            -1.080340            -0.922638
# 86   0.00001            -2.289931            -1.080103            -0.922797
#
#     time_constant_pow_3  time_constant_pow_4  time_constant_pow_5  verbose
# 0             -2.851175            -3.227471            -2.592922    False
# 1             -2.850509            -3.237315            -2.588350    False
# 2             -2.842887            -3.233751            -2.577247    False
# 3             -2.835404            -3.227464            -2.563589    False
# 4             -2.831566            -3.224091            -2.549747    False
# ..                  ...                  ...                  ...      ...
# 82            -3.360379            -3.616996            -2.296446    False
# 83            -3.360830            -3.617219            -2.296518    False
# 84            -3.361269            -3.617422            -2.296588    False
# 85            -3.361698            -3.617606            -2.296655    False
# 86            -3.362116            -3.617771            -2.296719    False
#
# [87 rows x 19 columns]

# %%
plot_loss_path(grid_search.best_estimator_.fit_results_)
plt.show()

# %%
plot_model(X, y, SklMultiExpFrequencyScan, grid_search.best_estimator_.fit_results_)
plt.legend(loc='lower left')
plt.show()

# %%
mean_squared_error(y, grid_search.best_estimator_.predict(X), squared=False)
# Out:
# 0.022247341310036105
