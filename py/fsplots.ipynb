# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
import numpy as np
import matplotlib.pyplot as plt
from fsplots import plot_spectr
from fsplots import plot_model
from fsplots import plot_loss_path
from fsplots import plot_deviations
from fsplots import plot_experimental_points

from fsmodels import SklMultiExpFrequencyScan, SklSingleExpFrequencyScan

# %matplotlib inline

# %%
exps_params = np.array([[-0.5, 2],
                        [-1, 1],
                        [-2, 2],
                        [-3, 1]
                       ])

# %% [markdown]
# # plot_spectr

# %%
plot_spectr(exps_params, ylim=[0,3])
plt.show()

# %% [markdown]
# # plot_model

# %%
X = np.linspace(0, 3.5, 1000)

fs = SklSingleExpFrequencyScan(filling_pulse = 20*10**-6,
                               fit_p_coef = True,
                               learning_rate = 0.1,
                               n_iters = 200, 
                               stop_val = 10**-5,
                               verbose = True)

fs.exps_params_ = [[-2.5, 3.5]]
fs.p_coef_ = 0.3

y = fs.predict(X)
y += np.random.normal(loc=0, scale=0.2, size=y.shape[0])

fs.fit(X, y)
# Out:
# 2022-09-21 06:28:14.515683: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-09-21 06:28:14.515709: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aleksei-B550I
# 2022-09-21 06:28:14.515715: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aleksei-B550I
# 2022-09-21 06:28:14.515830: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 515.65.1
# 2022-09-21 06:28:14.515845: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2022-09-21 06:28:14.515849: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 515.65.1
# 2022-09-21 06:28:14.516195: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# iteration # 0
# loss: 7.081652939749838
# exps_params:
# [[-1.74125662 -0.76309217]]
# p_coef: 1.0
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 6.532303896943997
# exps_params:
# [[-1.65275074 -0.54806202]]
# p_coef: 1.0786386558442946
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 6.15192807136473
# exps_params:
# [[-1.58568261 -0.36265322]]
# p_coef: 1.1275391841639837
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 5.874649541709012
# exps_params:
# [[-1.54017216 -0.19900465]]
# p_coef: 1.1567262388053632
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 4
# loss: 5.65936976880174
# exps_params:
# [[-1.51493268 -0.05127134]]
# p_coef: 1.171609925368041
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 5
# loss: 5.478509858207199
# exps_params:
# [[-1.50840508  0.08517037]]
# p_coef: 1.1752612549735004
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 6
# loss: 5.31233240331552
# exps_params:
# [[-1.5192576   0.21411126]]
# p_coef: 1.1693630318232053
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 7
# loss: 5.145466977704186
# exps_params:
# [[-1.54650705  0.33876916]]
# p_coef: 1.154674152460957
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 8
# loss: 4.964779460031144
# exps_params:
# [[-1.58943037  0.46196806]]
# p_coef: 1.1312674532234823
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 9
# loss: 4.758270796789271
# exps_params:
# [[-1.64733785  0.58624044]]
# p_coef: 1.0986481486074706
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 10
# loss: 4.514943000271321
# exps_params:
# [[-1.71922135  0.71384523]]
# p_coef: 1.0558082387430547
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 11
# loss: 4.225643712117013
# exps_params:
# [[-1.80328285  0.84668945]]
# p_coef: 1.0012516240217424
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 12
# loss: 3.884591895343151
# exps_params:
# [[-1.89640441  0.98615327]]
# p_coef: 0.9330125060885023
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 13
# loss: 3.4904261620830686
# exps_params:
# [[-1.99374903  1.13285681]]
# p_coef: 0.8486737968735867
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 14
# loss: 3.044731633085952
# exps_params:
# [[-2.08882265  1.28647011]]
# p_coef: 0.7453711833385861
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 15
# loss: 2.5469202826821755
# exps_params:
# [[-2.17430054  1.44568415]]
# p_coef: 0.6197876313064242
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 16
# loss: 1.9898549362463467
# exps_params:
# [[-2.2436218   1.60828031]]
# p_coef: 0.46844246697625413
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 17
# loss: 1.3818549484417186
# exps_params:
# [[-2.29334419  1.7706051 ]]
# p_coef: 0.29044972309448547
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 18
# loss: 0.9447842431981994
# exps_params:
# [[-2.32882508  1.92364149]]
# p_coef: 0.1082793895091042
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 19
# loss: 0.8007183627115944
# exps_params:
# [[-2.37857088  2.03496865]]
# p_coef: 0.15057148910620632
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 20
# loss: 0.6892591030128383
# exps_params:
# [[-2.41608726  2.14726678]]
# p_coef: 0.10139915635168398
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 21
# loss: 0.6647641903168556
# exps_params:
# [[-2.46721216  2.23061268]]
# p_coef: 0.242743121341926
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 22
# loss: 0.5419633594683765
# exps_params:
# [[-2.46539595  2.33994826]]
# p_coef: 0.09405124656557365
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 23
# loss: 0.6921970856024954
# exps_params:
# [[-2.52387489  2.39661907]]
# p_coef: 0.3568386172967385
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 24
# loss: 0.354982167014476
# exps_params:
# [[-2.48538858  2.49989992]]
# p_coef: 0.1750822925406359
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 25
# loss: 0.3076560523861109
# exps_params:
# [[-2.50726314  2.56916514]]
# p_coef: 0.15577591716190647
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 26
# loss: 0.2739280308715354
# exps_params:
# [[-2.53521054  2.62586132]]
# p_coef: 0.19700490015030683
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 27
# loss: 0.250412861555569
# exps_params:
# [[-2.53594395  2.68869952]]
# p_coef: 0.1433336427340258
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 28
# loss: 0.2651235182002793
# exps_params:
# [[-2.56931272  2.72848755]]
# p_coef: 0.254107710979734
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 29
# loss: 0.22809253183718495
# exps_params:
# [[-2.53715329  2.79256406]]
# p_coef: 0.135601869159597
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 30
# loss: 0.30968999666663743
# exps_params:
# [[-2.58179469  2.81684212]]
# p_coef: 0.3240233576188805
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 31
# loss: 0.1612307541670404
# exps_params:
# [[-2.52513285  2.88178376]]
# p_coef: 0.17208826116763243
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 32
# loss: 0.16267942695343554
# exps_params:
# [[-2.55364001  2.90926364]]
# p_coef: 0.2560262942010642
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 33
# loss: 0.14253956283359645
# exps_params:
# [[-2.53090556  2.95596886]]
# p_coef: 0.17167816760098492
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 34
# loss: 0.15597043017547094
# exps_params:
# [[-2.56154461  2.97532199]]
# p_coef: 0.2792478440946764
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 35
# loss: 0.12254136776156332
# exps_params:
# [[-2.52840934  3.01994224]]
# p_coef: 0.1809099958229941
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 36
# loss: 0.13215219217475146
# exps_params:
# [[-2.55728765  3.0353333 ]]
# p_coef: 0.2821919974272119
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 37
# loss: 0.10434198595006604
# exps_params:
# [[-2.52616384  3.07480532]]
# p_coef: 0.1926373355458384
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 38
# loss: 0.1079991927668003
# exps_params:
# [[-2.55129157  3.08807596]]
# p_coef: 0.27837733135576403
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 39
# loss: 0.08987674658942153
# exps_params:
# [[-2.52532093  3.12186679]]
# p_coef: 0.20386168377654734
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 40
# loss: 0.08998158707389267
# exps_params:
# [[-2.5463122   3.13367292]]
# p_coef: 0.2745083734147043
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 41
# loss: 0.07856225933666074
# exps_params:
# [[-2.52510371  3.16236975]]
# p_coef: 0.21453297881844102
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 42
# loss: 0.07691441644002736
# exps_params:
# [[-2.54192306  3.17317295]]
# p_coef: 0.2711541736309031
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 43
# loss: 0.06982902514804676
# exps_params:
# [[-2.52502833  3.19738515]]
# p_coef: 0.2246636085711827
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 44
# loss: 0.06759947262557657
# exps_params:
# [[-2.5378566   3.20751855]]
# p_coef: 0.2685211268915657
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 45
# loss: 0.06321389675319715
# exps_params:
# [[-2.52482867  3.22783092]]
# p_coef: 0.23415757181843042
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 46
# loss: 0.06106875731298398
# exps_params:
# [[-2.53403395  3.23750302]]
# p_coef: 0.2667736770470728
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 47
# loss: 0.05830656234589124
# exps_params:
# [[-2.52436111  3.25448602]]
# p_coef: 0.24283305110249576
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 48
# loss: 0.056527970655378096
# exps_params:
# [[-2.5304762   3.26378654]]
# p_coef: 0.266011335877694
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 49
# loss: 0.054716753062193695
# exps_params:
# [[-2.52356947  3.27799539]]
# p_coef: 0.25049440199050116
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 50
# loss: 0.05334217759041363
# exps_params:
# [[-2.52724004  3.28691671]]
# p_coef: 0.26622090660637515
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 51
# loss: 0.0520862716963927
# exps_params:
# [[-2.52247462  3.29887249]]
# p_coef: 0.25702002696467163
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 52
# loss: 0.05104404828584859
# exps_params:
# [[-2.52437351  3.30734761]]
# p_coef: 0.26726423851525993
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 53
# loss: 0.05012303687195624
# exps_params:
# [[-2.52115736  3.31750992]]
# p_coef: 0.2624182076861042
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 54
# loss: 0.04932443273784446
# exps_params:
# [[-2.52189144  3.32545617]]
# p_coef: 0.2689160045210596
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 55
# loss: 0.04861948579703531
# exps_params:
# [[-2.51972623  3.33420226]]
# p_coef: 0.2668181635829956
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 56
# loss: 0.04799597661644718
# exps_params:
# [[-2.51977253  3.34155546]]
# p_coef: 0.2709285536055735
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 57
# loss: 0.04744219215025873
# exps_params:
# [[-2.51828302  3.34917545]]
# p_coef: 0.2704120847411465
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 58
# loss: 0.04694826217704157
# exps_params:
# [[-2.51797174  3.35590567]]
# p_coef: 0.27308767274822565
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 59
# loss: 0.04650745369389787
# exps_params:
# [[-2.51690182  3.36261272]]
# p_coef: 0.2733927826157609
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 60
# loss: 0.046112976293145175
# exps_params:
# [[-2.51643643  3.36872353]]
# p_coef: 0.27523931820702907
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 61
# loss: 0.04576000880027804
# exps_params:
# [[-2.51562503  3.3746715 ]]
# p_coef: 0.27591730106707024
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 62
# loss: 0.045443723589058245
# exps_params:
# [[-2.51511795  3.38019084]]
# p_coef: 0.2772898069679342
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 63
# loss: 0.045160353340694084
# exps_params:
# [[-2.51446981  3.38549214]]
# p_coef: 0.2780984430784113
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 64
# loss: 0.04490627978116711
# exps_params:
# [[-2.51397639  3.39046174]]
# p_coef: 0.27919217850906414
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 65
# loss: 0.044678485713620916
# exps_params:
# [[-2.51343724  3.39520142]]
# p_coef: 0.28001194716956834
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 66
# loss: 0.04447416601775613
# exps_params:
# [[-2.51298085  3.39966861]]
# p_coef: 0.2809299086150693
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 67
# loss: 0.044290894984947544
# exps_params:
# [[-2.51251992  3.40391405]]
# p_coef: 0.28170783727319276
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 68
# loss: 0.04412646027939297
# exps_params:
# [[-2.51210771  3.40792649]]
# p_coef: 0.2825036909165628
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 69
# loss: 0.04397891352662356
# exps_params:
# [[-2.511707    3.41173341]]
# p_coef: 0.28322012407455055
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 70
# loss: 0.04384649529488266
# exps_params:
# [[-2.51133866  3.41533637]]
# p_coef: 0.2839226517161786
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 71
# loss: 0.04372764217110331
# exps_params:
# [[-2.51098688  3.41875233]]
# p_coef: 0.2845733718590902
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 72
# loss: 0.04362094888558178
# exps_params:
# [[-2.51065914  3.42198754]]
# p_coef: 0.28519926614889196
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 73
# loss: 0.04352516124715923
# exps_params:
# [[-2.51034855  3.42505399]]
# p_coef: 0.2857865963660136
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 74
# loss: 0.04343915408618201
# exps_params:
# [[-2.51005729  3.42795924]]
# p_coef: 0.2863467340201428
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 75
# loss: 0.04336192096729968
# exps_params:
# [[-2.5097821   3.43071278]]
# p_coef: 0.28687540253950344
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 76
# loss: 0.04329255954711362
# exps_params:
# [[-2.5095232  3.4333221]]
# p_coef: 0.28737777260920344
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 77
# loss: 0.04323026172795625
# exps_params:
# [[-2.50927881  3.43579521]]
# p_coef: 0.2878531137588838
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 78
# loss: 0.04317430302150338
# exps_params:
# [[-2.50904849  3.43813912]]
# p_coef: 0.28830414302610297
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 79
# loss: 0.04312403413329614
# exps_params:
# [[-2.50883109  3.44036078]]
# p_coef: 0.28873137283782735
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 80
# loss: 0.043078872836742714
# exps_params:
# [[-2.50862599  3.44246658]]
# p_coef: 0.2891365229396917
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 81
# loss: 0.04303829707005021
# exps_params:
# [[-2.50843234  3.44446268]]
# p_coef: 0.28952048140045045
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 82
# loss: 0.043001838570569564
# exps_params:
# [[-2.50824951  3.44635484]]
# p_coef: 0.289884527913064
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 83
# loss: 0.04296907730041865
# exps_params:
# [[-2.50807683  3.44814853]]
# p_coef: 0.29022961258966634
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 84
# loss: 0.04293963640015584
# exps_params:
# [[-2.5079137   3.44984893]]
# p_coef: 0.29055678838407023
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 85
# loss: 0.0429131777126662
# exps_params:
# [[-2.50775957  3.45146095]]
# p_coef: 0.2908669612509636
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 86
# loss: 0.04288939775966256
# exps_params:
# [[-2.5076139   3.45298921]]
# p_coef: 0.2911610417776162
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 87
# loss: 0.04286802415316677
# exps_params:
# [[-2.5074762   3.45443811]]
# p_coef: 0.29143986093791824
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 88
# loss: 0.04284881237783283
# exps_params:
# [[-2.50734601  3.4558118 ]]
# p_coef: 0.29170422352113734
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 89
# loss: 0.04283154291401031
# exps_params:
# [[-2.50722291  3.45711422]]
# p_coef: 0.2919548810503584
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 90
# loss: 0.042816018659826344
# exps_params:
# [[-2.50710649  3.4583491 ]]
# p_coef: 0.29219255125502297
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 91
# loss: 0.042802062623381786
# exps_params:
# [[-2.50699636  3.45951996]]
# p_coef: 0.29241791034537584
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 92
# loss: 0.042789515854768596
# exps_params:
# [[-2.50689217  3.46063014]]
# p_coef: 0.29263160079897654
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 93
# loss: 0.042778235593405683
# exps_params:
# [[-2.50679359  3.46168282]]
# p_coef: 0.2928342300138397
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 94
# loss: 0.04276809360746746
# exps_params:
# [[-2.50670031  3.46268098]]
# p_coef: 0.2930263740332078
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 95
# loss: 0.042758974705444104
# exps_params:
# [[-2.50661202  3.46362746]]
# p_coef: 0.2932085781928376
# filling_pulse: 1.9999999999999998e-05
# fit_p_coef: True
# learning_rate: 0.1
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# SklSingleExpFrequencyScan(n_iters=200, stop_val=1e-05, verbose=True)

# %%
plot_model(X, y, SklSingleExpFrequencyScan, fs.fit_results_)
plt.show()

# %%
X = np.linspace(0, 3.5, 1000)

fs = SklMultiExpFrequencyScan(filling_pulse = 20*10**-6,
                              n_exps = 3,
                              learning_rate = 0.1,
                              n_iters = 200, 
                              stop_val = 10**-5,
                              verbose = True)

fs.exps_params_ = [[-1.0, 3.5],
                   [-2.3, 3.0],
                   [-3.5, 2.5]]

y = fs.predict(X)
y += np.random.normal(loc=0, scale=0.2, size=y.shape[0])

fs.fit(X, y)
# Out:
# iteration # 0
# loss: 8.360913776001086
# exps_params:
# [[-3.4837996   0.2411688 ]
#  [-3.1992775   0.28301552]
#  [-2.43977435 -0.00774351]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 1
# loss: 7.497688439570446
# exps_params:
# [[-3.45271925  0.36807927]
#  [-3.16974786  0.44059458]
#  [-2.44019866  0.21027024]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 2
# loss: 6.770931007697149
# exps_params:
# [[-3.41250036  0.48252933]
#  [-3.12900353  0.58136865]
#  [-2.42661276  0.40919939]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 3
# loss: 6.152350425063705
# exps_params:
# [[-3.36896254  0.58616117]
#  [-3.0818391   0.70731   ]
#  [-2.39701192  0.590718  ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 4
# loss: 5.6180497646410945
# exps_params:
# [[-3.32643225  0.6800968 ]
#  [-3.03165345  0.82004931]
#  [-2.35110524  0.75683547]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 5
# loss: 5.147126340376846
# exps_params:
# [[-3.287816    0.7653979 ]
#  [-2.98067056  0.92120237]
#  [-2.29005664  0.90981252]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 6
# loss: 4.722400920648084
# exps_params:
# [[-3.25479047  0.84324439]
#  [-2.93024845  1.01246   ]
#  [-2.21604454  1.05193558]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 7
# loss: 4.330709219686472
# exps_params:
# [[-3.22803178  0.91492336]
#  [-2.88110589  1.09555124]
#  [-2.13168018  1.18528745]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 8
# loss: 3.961984795542434
# exps_params:
# [[-3.20743356  0.98172957]
#  [-2.83343929  1.17216751]
#  [-2.0393424   1.31161208]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 9
# loss: 3.607787118870382
# exps_params:
# [[-3.19231926  1.04485956]
#  [-2.78698872  1.24389944]
#  [-1.94063366  1.43230586]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 10
# loss: 3.260488614343597
# exps_params:
# [[-3.18165829  1.10534508]
#  [-2.74110907  1.31220754]
#  [-1.83627463  1.54849629]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 11
# loss: 2.914136727099244
# exps_params:
# [[-3.1742796   1.16402961]
#  [-2.69486896  1.37841533]
#  [-1.72666347  1.66112175]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 12
# loss: 2.567538833502643
# exps_params:
# [[-3.1690837   1.22156571]
#  [-2.64720725  1.44368804]
#  [-1.61313902  1.77091928]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 13
# loss: 2.228517273941389
# exps_params:
# [[-3.16525587  1.27841243]
#  [-2.59722993  1.50895353]
#  [-1.49965945  1.87825098]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 14
# loss: 1.914096400544316
# exps_params:
# [[-3.16243906  1.33483138]
#  [-2.54473632  1.57474896]
#  [-1.3936871   1.98279921]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 15
# loss: 1.6408624564330025
# exps_params:
# [[-3.16075086  1.39089598]
#  [-2.49085822  1.64105006]
#  [-1.30409192  2.08341698]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 16
# loss: 1.413500816894743
# exps_params:
# [[-3.1605499   1.44652135]
#  [-2.43826791  1.70722997]
#  [-1.23604109  2.17854391]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 17
# loss: 1.2261505354079918
# exps_params:
# [[-3.16207883  1.50149881]
#  [-2.3903658   1.77227103]
#  [-1.18801093  2.26700244]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 18
# loss: 1.070728126005571
# exps_params:
# [[-3.16529198  1.55552223]
#  [-2.34981078  1.83514384]
#  [-1.15446697  2.34840505]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 19
# loss: 0.9405567676014782
# exps_params:
# [[-3.16996531  1.60822605]
#  [-2.31760161  1.89510303]
#  [-1.13009401  2.42299331]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 20
# loss: 0.830436191382807
# exps_params:
# [[-3.17587281  1.65924629]
#  [-2.2932456   1.95176318]
#  [-1.11146795  2.49132425]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 21
# loss: 0.7363502025493822
# exps_params:
# [[-3.18285257  1.70827924]
#  [-2.27547245  2.00502219]
#  [-1.09671051  2.55404885]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 22
# loss: 0.6552549115411482
# exps_params:
# [[-3.1907801   1.75511226]
#  [-2.26285209  2.05495191]
#  [-1.08477442  2.61179739]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 23
# loss: 0.5848548494595673
# exps_params:
# [[-3.19952603  1.79962565]
#  [-2.25411533  2.10171564]
#  [-1.07499722  2.6651332 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 24
# loss: 0.5233977040545428
# exps_params:
# [[-3.20893664  1.84177795]
#  [-2.24825155  2.14551794]
#  [-1.06690671  2.71454224]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 25
# loss: 0.46951768370282243
# exps_params:
# [[-3.21883765  1.88158607]
#  [-2.24449787  2.18657605]
#  [-1.06014613  2.7604382 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 26
# loss: 0.42212617815491704
# exps_params:
# [[-3.22904906  1.91910674]
#  [-2.24229207  2.22510368]
#  [-1.05444125  2.80317262]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 27
# loss: 0.3803373498831214
# exps_params:
# [[-3.23940088  1.95442174]
#  [-2.24122257  2.26130229]
#  [-1.04958043  2.84304541]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 28
# loss: 0.34341726028181985
# exps_params:
# [[-3.2497444   1.9876273 ]
#  [-2.24098701  2.29535695]
#  [-1.04539978  2.88031414]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 29
# loss: 0.3107485716752675
# exps_params:
# [[-3.2599579   2.01882686]
#  [-2.24136135  2.32743523]
#  [-1.04177175  2.91520173]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 30
# loss: 0.28180564489661425
# exps_params:
# [[-3.26994764  2.0481264 ]
#  [-2.24217811  2.35768764]
#  [-1.03859632  2.94790265]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 31
# loss: 0.2561366357791776
# exps_params:
# [[-3.27964569  2.07563146]
#  [-2.24331126  2.38624916]
#  [-1.03579457  2.97858783]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 32
# loss: 0.23335033547773434
# exps_params:
# [[-3.28900629  2.10144529]
#  [-2.24466563  2.4132409 ]
#  [-1.03330384  3.00740866]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 33
# loss: 0.2131062428252367
# exps_params:
# [[-3.29800156  2.12566771]
#  [-2.24616942  2.43877194]
#  [-1.0310741   3.03450017]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 34
# loss: 0.1951068611845054
# exps_params:
# [[-3.3066175   2.14839439]
#  [-2.24776864  2.46294092]
#  [-1.02906529  3.05998356]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 35
# loss: 0.17909155405972194
# exps_params:
# [[-3.31485046  2.16971646]
#  [-2.24942297  2.48583746]
#  [-1.02724514  3.08396838]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 36
# loss: 0.1648315220884297
# exps_params:
# [[-3.32270423  2.18972034]
#  [-2.25110251  2.50754338]
#  [-1.02558757  3.10655412]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 37
# loss: 0.15212561340340622
# exps_params:
# [[-3.33018774  2.20848765]
#  [-2.25278532  2.52813365]
#  [-1.02407136  3.12783169]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 38
# loss: 0.14079677520034467
# exps_params:
# [[-3.33731332  2.22609527]
#  [-2.2544555   2.54767725]
#  [-1.02267914  3.14788446]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 39
# loss: 0.13068901507221323
# exps_params:
# [[-3.34409537  2.24261545]
#  [-2.25610166  2.56623786]
#  [-1.02139658  3.16678925]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 40
# loss: 0.12166477901154837
# exps_params:
# [[-3.35054941  2.258116  ]
#  [-2.25771583  2.58387439]
#  [-1.02021174  3.18461703]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 41
# loss: 0.11360267738718294
# exps_params:
# [[-3.35669138  2.27266046]
#  [-2.25929255  2.60064152]
#  [-1.01911455  3.2014336 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 42
# loss: 0.10639550607194292
# exps_params:
# [[-3.36253719  2.28630829]
#  [-2.26082825  2.61659005]
#  [-1.01809646  3.21730009]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 43
# loss: 0.09994852058055127
# exps_params:
# [[-3.3681024   2.29911518]
#  [-2.2623207   2.63176727]
#  [-1.01715014  3.23227341]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 44
# loss: 0.09417792859820512
# exps_params:
# [[-3.37340199  2.31113318]
#  [-2.26376868  2.6462173 ]
#  [-1.01626919  3.24640664]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 45
# loss: 0.08900957184340946
# exps_params:
# [[-3.37845026  2.32241098]
#  [-2.26517169  2.65998129]
#  [-1.01544802  3.25974936]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 46
# loss: 0.08437777252075951
# exps_params:
# [[-3.38326077  2.33299413]
#  [-2.26652976  2.67309771]
#  [-1.01468168  3.2723479 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 47
# loss: 0.08022432300177874
# exps_params:
# [[-3.38784632  2.34292519]
#  [-2.26784328  2.68560253]
#  [-1.01396577  3.28424565]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 48
# loss: 0.07649760091788224
# exps_params:
# [[-3.39221894  2.352244  ]
#  [-2.26911291  2.69752943]
#  [-1.01329632  3.29548324]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 49
# loss: 0.07315179226835979
# exps_params:
# [[-3.39638993  2.36098781]
#  [-2.27033948  2.70890994]
#  [-1.01266975  3.30609878]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 50
# loss: 0.07014621066273498
# exps_params:
# [[-3.40036987  2.3691915 ]
#  [-2.27152396  2.71977362]
#  [-1.01208284  3.31612799]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 51
# loss: 0.06744469913791254
# exps_params:
# [[-3.40416868  2.3768877 ]
#  [-2.27266738  2.7301482 ]
#  [-1.01153261  3.32560442]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 52
# loss: 0.06501510467769739
# exps_params:
# [[-3.40779568  2.38410696]
#  [-2.27377084  2.74005968]
#  [-1.01101638  3.33455956]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 53
# loss: 0.06282881620111702
# exps_params:
# [[-3.41125958  2.3908779 ]
#  [-2.27483547  2.7495325 ]
#  [-1.01053168  3.34302298]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 54
# loss: 0.06086035806873873
# exps_params:
# [[-3.41456858  2.39722735]
#  [-2.2758624   2.75858959]
#  [-1.01007623  3.35102249]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 55
# loss: 0.059087032181181394
# exps_params:
# [[-3.41773036  2.40318043]
#  [-2.27685276  2.76725252]
#  [-1.00964795  3.35858424]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 56
# loss: 0.05748860263473408
# exps_params:
# [[-3.42075215  2.40876072]
#  [-2.27780769  2.77554156]
#  [-1.00924492  3.36573279]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 57
# loss: 0.05604701767297945
# exps_params:
# [[-3.42364076  2.41399032]
#  [-2.27872831  2.78347579]
#  [-1.00886535  3.37249129]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 58
# loss: 0.054746164346061714
# exps_params:
# [[-3.42640261  2.41888997]
#  [-2.27961573  2.79107316]
#  [-1.00850763  3.37888149]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 59
# loss: 0.053571651873781094
# exps_params:
# [[-3.42904373  2.42347913]
#  [-2.28047103  2.79835058]
#  [-1.00817023  3.38492388]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 60
# loss: 0.05251062021673609
# exps_params:
# [[-3.43156986  2.42777608]
#  [-2.28129527  2.80532398]
#  [-1.00785176  3.39063775]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 61
# loss: 0.05155157080163755
# exps_params:
# [[-3.43398637  2.431798  ]
#  [-2.28208951  2.81200836]
#  [-1.00755093  3.39604127]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 62
# loss: 0.05068421673098871
# exps_params:
# [[-3.43629839  2.43556099]
#  [-2.28285475  2.8184179 ]
#  [-1.00726655  3.40115156]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 63
# loss: 0.049899350141800136
# exps_params:
# [[-3.43851075  2.43908024]
#  [-2.283592    2.82456593]
#  [-1.00699752  3.40598475]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 64
# loss: 0.04918872466877235
# exps_params:
# [[-3.44062804  2.44236997]
#  [-2.28430222  2.83046507]
#  [-1.00674281  3.41055604]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 65
# loss: 0.04854495122114767
# exps_params:
# [[-3.44265462  2.44544361]
#  [-2.28498637  2.83612723]
#  [-1.00650148  3.41487977]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 66
# loss: 0.04796140550312778
# exps_params:
# [[-3.44459461  2.44831374]
#  [-2.28564536  2.84156364]
#  [-1.00627265  3.41896947]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 67
# loss: 0.04743214590046267
# exps_params:
# [[-3.44645195  2.45099223]
#  [-2.2862801   2.84678494]
#  [-1.00605551  3.42283788]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 68
# loss: 0.04695184052405045
# exps_params:
# [[-3.44823036  2.45349025]
#  [-2.28689144  2.85180117]
#  [-1.00584932  3.42649703]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 69
# loss: 0.04651570234800316
# exps_params:
# [[-3.44993339  2.4558183 ]
#  [-2.28748025  2.85662184]
#  [-1.00565337  3.42995829]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 70
# loss: 0.046119431508130915
# exps_params:
# [[-3.45156443  2.45798628]
#  [-2.28804734  2.86125596]
#  [-1.00546702  3.43323237]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 71
# loss: 0.045759163938884774
# exps_params:
# [[-3.45312669  2.46000351]
#  [-2.2885935   2.86571202]
#  [-1.00528967  3.43632939]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 72
# loss: 0.04543142562498544
# exps_params:
# [[-3.45462324  2.46187876]
#  [-2.28911952  2.86999812]
#  [-1.00512078  3.4392589 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 73
# loss: 0.04513309183003847
# exps_params:
# [[-3.456057    2.46362033]
#  [-2.28962615  2.87412188]
#  [-1.00495981  3.44202993]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 74
# loss: 0.044861350739755335
# exps_params:
# [[-3.45743075  2.465236  ]
#  [-2.2901141   2.87809057]
#  [-1.0048063   3.444651  ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 75
# loss: 0.044613671023486755
# exps_params:
# [[-3.45874715  2.46673312]
#  [-2.29058408  2.88191105]
#  [-1.0046598   3.44713018]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 76
# loss: 0.044387772875848136
# exps_params:
# [[-3.46000873  2.46811863]
#  [-2.29103677  2.88558984]
#  [-1.0045199   3.44947507]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 77
# loss: 0.04418160215115117
# exps_params:
# [[-3.4612179   2.46939906]
#  [-2.29147283  2.88913313]
#  [-1.00438622  3.45169286]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 78
# loss: 0.043993307248172756
# exps_params:
# [[-3.46237697  2.47058058]
#  [-2.29189289  2.89254681]
#  [-1.00425839  3.45379036]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 79
# loss: 0.04382121844219684
# exps_params:
# [[-3.46348814  2.47166901]
#  [-2.29229756  2.89583645]
#  [-1.00413609  3.455774  ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 80
# loss: 0.043663829395932774
# exps_params:
# [[-3.46455351  2.47266982]
#  [-2.29268744  2.89900737]
#  [-1.00401901  3.45764986]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 81
# loss: 0.04351978061155009
# exps_params:
# [[-3.46557509  2.47358821]
#  [-2.29306309  2.9020646 ]
#  [-1.00390685  3.4594237 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 82
# loss: 0.043387844612910724
# exps_params:
# [[-3.46655479  2.47442905]
#  [-2.29342507  2.90501294]
#  [-1.00379936  3.46110094]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 83
# loss: 0.04326691267094002
# exps_params:
# [[-3.46749443  2.47519696]
#  [-2.29377391  2.90785695]
#  [-1.00369628  3.46268675]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 84
# loss: 0.04315598290601292
# exps_params:
# [[-3.46839577  2.47589629]
#  [-2.29411012  2.91060097]
#  [-1.00359738  3.46418598]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 85
# loss: 0.04305414961977635
# exps_params:
# [[-3.46926046  2.47653115]
#  [-2.29443419  2.91324915]
#  [-1.00350243  3.46560324]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 86
# loss: 0.04296059372522771
# exps_params:
# [[-3.47009011  2.47710542]
#  [-2.2947466   2.91580541]
#  [-1.00341125  3.46694291]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 87
# loss: 0.042874574158343066
# exps_params:
# [[-3.47088623  2.47762276]
#  [-2.2950478   2.9182735 ]
#  [-1.00332362  3.4682091 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 88
# loss: 0.04279542016746768
# exps_params:
# [[-3.47165028  2.47808664]
#  [-2.29533823  2.920657  ]
#  [-1.00323938  3.46940572]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 89
# loss: 0.04272252438786627
# exps_params:
# [[-3.47238364  2.47850031]
#  [-2.29561832  2.92295932]
#  [-1.00315837  3.47053647]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 90
# loss: 0.04265533661916087
# exps_params:
# [[-3.47308764  2.47886687]
#  [-2.29588846  2.92518369]
#  [-1.00308041  3.47160485]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 91
# loss: 0.04259335823208684
# exps_params:
# [[-3.47376355  2.47918922]
#  [-2.29614906  2.92733323]
#  [-1.00300537  3.47261419]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 92
# loss: 0.04253613713905088
# exps_params:
# [[-3.47441257  2.47947012]
#  [-2.29640049  2.92941089]
#  [-1.00293311  3.47356761]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 93
# loss: 0.04248326327005849
# exps_params:
# [[-3.47503588  2.47971216]
#  [-2.2966431   2.93141949]
#  [-1.00286349  3.4744681 ]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 94
# loss: 0.04243436450170469
# exps_params:
# [[-3.47563456  2.4799178 ]
#  [-2.29687725  2.93336173]
#  [-1.00279641  3.47531847]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 95
# loss: 0.042389102992612025
# exps_params:
# [[-3.47620967  2.48008936]
#  [-2.29710327  2.93524017]
#  [-1.00273173  3.47612138]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 96
# loss: 0.042347171883588434
# exps_params:
# [[-3.47676223  2.48022902]
#  [-2.29732147  2.93705728]
#  [-1.00266936  3.47687937]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 97
# loss: 0.042308292325200295
# exps_params:
# [[-3.4772932   2.48033884]
#  [-2.29753216  2.93881541]
#  [-1.00260919  3.47759484]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 98
# loss: 0.042272210799408697
# exps_params:
# [[-3.47780349  2.48042078]
#  [-2.29773565  2.94051679]
#  [-1.00255112  3.47827003]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 99
# loss: 0.04223869670538468
# exps_params:
# [[-3.47829399  2.48047669]
#  [-2.2979322   2.94216358]
#  [-1.00249507  3.47890712]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 100
# loss: 0.0422075401827131
# exps_params:
# [[-3.47876554  2.4805083 ]
#  [-2.29812209  2.94375784]
#  [-1.00244095  3.47950812]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# iteration # 101
# loss: 0.042178550148090084
# exps_params:
# [[-3.47921895  2.48051724]
#  [-2.29830558  2.94530152]
#  [-1.00238868  3.48007498]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 102
# loss: 0.042151552523979986
# exps_params:
# [[-3.47965498  2.48050509]
#  [-2.29848292  2.9467965 ]
#  [-1.00233819  3.48060952]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 103
# loss: 0.04212638863996539
# exps_params:
# [[-3.48007436  2.48047329]
#  [-2.29865436  2.94824459]
#  [-1.00228939  3.48111346]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 104
# loss: 0.042102913789568076
# exps_params:
# [[-3.4804778   2.48042322]
#  [-2.29882011  2.9496475 ]
#  [-1.00224222  3.48158845]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 105
# loss: 0.04208099592693965
# exps_params:
# [[-3.48086596  2.4803562 ]
#  [-2.29898039  2.95100688]
#  [-1.00219662  3.48203605]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 106
# loss: 0.04206051448961792
# exps_params:
# [[-3.4812395   2.48027345]
#  [-2.29913543  2.95232432]
#  [-1.00215252  3.48245773]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 107
# loss: 0.042041359334738855
# exps_params:
# [[-3.48159901  2.48017613]
#  [-2.29928542  2.95360133]
#  [-1.00210987  3.48285488]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 108
# loss: 0.04202342977755247
# exps_params:
# [[-3.48194509  2.48006533]
#  [-2.29943055  2.95483936]
#  [-1.00206861  3.48322883]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 109
# loss: 0.042006633722122926
# exps_params:
# [[-3.48227829  2.47994209]
#  [-2.29957101  2.9560398 ]
#  [-1.00202868  3.48358083]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 110
# loss: 0.04199088687511495
# exps_params:
# [[-3.48259915  2.47980738]
#  [-2.29970698  2.95720397]
#  [-1.00199004  3.48391207]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 111
# loss: 0.04197611203457929
# exps_params:
# [[-3.48290818  2.47966212]
#  [-2.29983863  2.95833317]
#  [-1.00195264  3.48422368]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 112
# loss: 0.04196223844628659
# exps_params:
# [[-3.48320587  2.47950717]
#  [-2.29996612  2.95942862]
#  [-1.00191643  3.48451672]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 113
# loss: 0.041949201221137614
# exps_params:
# [[-3.48349269  2.47934334]
#  [-2.30008961  2.96049149]
#  [-1.00188137  3.48479219]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 114
# loss: 0.04193694080759752
# exps_params:
# [[-3.48376908  2.47917141]
#  [-2.30020925  2.96152291]
#  [-1.00184741  3.48505107]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 115
# loss: 0.041925402513855084
# exps_params:
# [[-3.48403547  2.4789921 ]
#  [-2.30032519  2.96252397]
#  [-1.00181452  3.48529426]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 116
# loss: 0.04191453607487381
# exps_params:
# [[-3.48429227  2.47880608]
#  [-2.30043755  2.9634957 ]
#  [-1.00178265  3.48552262]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 117
# loss: 0.041904295259996095
# exps_params:
# [[-3.48453986  2.478614  ]
#  [-2.30054648  2.96443912]
#  [-1.00175178  3.48573695]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
#
#
# iteration # 118
# loss: 0.04189463751719315
# exps_params:
# [[-3.48477863  2.47841646]
#  [-2.30065209  2.96535516]
#  [-1.00172187  3.48593804]]
# filling_pulse: 1.9999999999999998e-05
# learning_rate: 0.1
# n_exps: 3
# n_iters: 200
# stop_val: 1e-05
# verbose: True
# SklMultiExpFrequencyScan(n_exps=3, n_iters=200, stop_val=1e-05, verbose=True)

# %%
plot_model(X, y, SklMultiExpFrequencyScan, fs.fit_results_)
plt.show()

# %% [markdown]
# # plot_loss_path

# %%
plot_loss_path(fs.fit_results_)
plt.show()

# %% [markdown]
# # plot_deviations

# %%
plot_deviations(X, y, fs.predict(X))
plt.show()

# %% [markdown]
# # plot_experimental_points

# %%
plot_experimental_points(X, y)
plt.show()
