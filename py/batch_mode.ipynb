# %%
from ExperimentalDataReader import DataReader
from matplotlib import pyplot as plt
from os import listdir
import pandas as pd
import regex as re

# %matplotlib inline

# %%
def get_meta_data(datasets_folder='datasets/raw_data/', integral_time=3.0, time_between_meas=3.5):
    
    def get_file_names(datasets_folder=datasets_folder):
        files=pd.DataFrame({'file_names': listdir(datasets_folder)})

        data_files = files.loc[~files.file_names.str.startswith('Температура')]
        temperature_files = files.loc[files.file_names.str.startswith('Температура')].reset_index()

        files = pd.DataFrame({'data_files': data_files.file_names,
                              'temperature_files': temperature_files.file_names
                             })

        return files
    
    def get_params(files, integral_time, time_between_meas):
        files['patterns'] = files.data_files.str.split('_')
        
        get_spc_name = lambda x: ' '.join(x[:2])
        files['specimen_name'] = files.patterns.apply(get_spc_name)
        
        get_bs = lambda x: int(x[3].strip('пФ'))
        files['bs'] = files.patterns.apply(get_bs)
        
        get_u1 = lambda x: float(re.findall(string=x[5], pattern=r'[+-]?\d+\.?\d*')[0])
        files['u1'] = files.patterns.apply(get_u1)
        
        get_ur = lambda x: float(re.findall(string=x[5], pattern=r'[+-]?\d+\.?\d*')[-1])
        files['ur'] = files.patterns.apply(get_ur)
        
        get_ls = lambda x: int(x[6].strip('мВ'))
        files['ls'] = files.patterns.apply(get_ls)
        
        get_f_pulse = lambda x: float(x[7].strip('мкс'))
        files['f_pulse'] = files.patterns.apply(get_f_pulse)
        
        files['time_between_meas'] = time_between_meas
        files['integral_time'] = integral_time
        
        return files.drop('patterns', axis='columns')
    
    files = get_file_names()
    return get_params(files, integral_time, time_between_meas)

# %%
def prepare_data(meta_data, folder='datasets/raw_data'):
    data_reader = DataReader()
    
    folder = folder
    d_file_name = folder + '/' + meta_data.data_files
    t_file_name = folder + '/' + meta_data.temperature_files

    data_reader.read_from_d_t(d_file_name=d_file_name, t_file_name=t_file_name)

    data_reader.set_bs(meta_data.bs)

    data_reader.set_ls(meta_data.ls)

    data_reader.set_f_pulse(meta_data.f_pulse)

    data_reader.compute_dlts_pf()

    data_reader.set_specimen_name(meta_data.specimen_name)

    data_reader.set_u1(meta_data.u1)

    data_reader.set_ur(meta_data.ur)

    data_reader.set_time_between_meas(meta_data.time_between_meas)

    data_reader.set_integral_time(meta_data.integral_time)
    
    return data_reader

# %%
RAW_DATA_PATH = '../raw_data'
DATASET_PATH = '../dataset'
PLOTS_PATH = '../plots'

# %%
meta_data = get_meta_data(datasets_folder=RAW_DATA_PATH)

# %%
data_readers = meta_data.apply(prepare_data, axis='columns', folder=RAW_DATA_PATH)

plots_folder = PLOTS_PATH
dataset_folder = DATASET_PATH

for i, data_reader in enumerate(data_readers):
    data_reader.to_csv(dataset_folder + '/' + meta_data.data_files[i] + '.csv')
    
    data_reader.get_plot()
    plt.savefig(plots_folder + '/' + meta_data.data_files[i] + '.jpg')
    plt.savefig(plots_folder + '/' + meta_data.data_files[i] + '.svg')
    
    plt.close('all')
    print(f'№{i}\t{meta_data.data_files[i]}\t- OK')
# Out:
# №0	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-10В-11В_10мВ_20мкс_шаг_0,1	- OK
# №1	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-10В-12В_20мВ_20мкс_шаг_0,1	- OK
# №2	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-11В-12В_20мВ_20мкс_шаг_0,1	- OK
# №3	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-10В_200мВ_20мкс_шаг_0,1	- OK
# №4	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-11В_200мВ_20мкс_шаг_0,1	- OK
# №5	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-12В_200мВ_20мкс_шаг_0,1	- OK
# №6	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-2В_100мВ_20мкс_шаг_0,1	- OK
# №7	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-3В_200мВ_20мкс_шаг_0,1	- OK
# №8	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-4В_200мВ_20мкс_шаг_0,1	- OK
# №9	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-5В_200мВ_20мкс_шаг_0,1	- OK
# №10	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-6В_200мВ_20мкс_шаг_0,1	- OK
# №11	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-7В_200мВ_20мкс_шаг_0,1	- OK
# №12	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-8В_200мВ_20мкс_шаг_0,1	- OK
# №13	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-1В-9В_200мВ_20мкс_шаг_0,1	- OK
# №14	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-10В_200мВ_20мкс_шаг_0,1	- OK
# №15	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-11В_200мВ_20мкс_шаг_0,1	- OK
# №16	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-12В_200мВ_20мкс_шаг_0,1	- OK
# №17	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-3В_50мВ_20мкс_шаг_0,1	- OK
# №18	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-4В_100мВ_20мкс_шаг_0,1	- OK
# №19	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-5В_200мВ_20мкс_шаг_0,1	- OK
# №20	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-6В_200мВ_20мкс_шаг_0,1	- OK
# №21	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-7В_200мВ_20мкс_шаг_0,1	- OK
# №22	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-8В_200мВ_20мкс_шаг_0,1	- OK
# №23	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-2В-9В_200мВ_20мкс_шаг_0,1	- OK
# №24	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-10В_200мВ_20мкс_шаг_0,1	- OK
# №25	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-11В_200мВ_20мкс_шаг_0,1	- OK
# №26	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-12В_200мВ_20мкс_шаг_0,1	- OK
# №27	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-4В_20мВ_20мкс_шаг_0,1	- OK
# №28	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-5В_50мВ_20мкс_шаг_0,1	- OK
# №29	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-6В_100мВ_20мкс_шаг_0,1	- OK
# №30	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-7В_200мВ_20мкс_шаг_0,1	- OK
# №31	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-8В_200мВ_20мкс_шаг_0,1	- OK
# №32	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-3В-9В_200мВ_20мкс_шаг_0,1	- OK
# №33	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-10В_200мВ_20мкс_шаг_0,1	- OK
# №34	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-11В_200мВ_20мкс_шаг_0,1	- OK
# №35	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-12В_200мВ_20мкс_шаг_0,1	- OK
# №36	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-5В_50мВ_20мкс_шаг_0,1	- OK
# №37	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-6В_50мВ_20мкс_шаг_0,1	- OK
# №38	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-7В_100мВ_20мкс_шаг_0,1	- OK
# №39	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-8В_100мВ_20мкс_шаг_0,1	- OK
# №40	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-4В-9В_200мВ_20мкс_шаг_0,1	- OK
# №41	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-10В_100мВ_20мкс_шаг_0,1	- OK
# №42	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-11В_100мВ_20мкс_шаг_0,1	- OK
# №43	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-12В_200мВ_20мкс_шаг_0,1	- OK
# №44	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-6В_10мВ_20мкс_шаг_0,1	- OK
# №45	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-7В_50мВ_20мкс_шаг_0,1	- OK
# №46	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-8В_100мВ_20мкс_шаг_0,1	- OK
# №47	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-5В-9В_100мВ_20мкс_шаг_0,1	- OK
# №48	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-10В_100мВ_20мкс_шаг_0,1	- OK
# №49	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-11В_100мВ_20мкс_шаг_0,1	- OK
# №50	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-12В_100мВ_20мкс_шаг_0,1	- OK
# №51	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-7В_10мВ_20мкс_шаг_0,1	- OK
# №52	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-8В_50мВ_20мкс_шаг_0,1	- OK
# №53	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-6В-9В_100мВ_20мкс_шаг_0,1	- OK
# №54	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-7В-10В_50мВ_20мкс_шаг_0,1	- OK
# №55	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-7В-11В_100мВ_20мкс_шаг_0,1	- OK
# №56	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-7В-12В_100мВ_20мкс_шаг_0,1	- OK
# №57	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-7В-8В_10мВ_20мкс_шаг_0,1	- OK
# №58	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-7В-9В_50мВ_20мкс_шаг_0,1	- OK
# №59	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-8В-10В_20мВ_20мкс_шаг_0,1	- OK
# №60	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-8В-11В_50мВ_20мкс_шаг_0,1	- OK
# №61	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-8В-12В_100мВ_20мкс_шаг_0,1	- OK
# №62	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-8В-9В_10мВ_20мкс_шаг_0,1	- OK
# №63	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-9В-10В_20мВ_20мкс_шаг_0,1	- OK
# №64	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-9В-11В_50мВ_20мкс_шаг_0,1	- OK
# №65	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+10С_-9В-12В_50мВ_20мкс_шаг_0,1	- OK
# №66	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-10В-11В_10мВ_20мкс_шаг_0,1	- OK
# №67	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-10В-12В_20мВ_20мкс_шаг_0,1	- OK
# №68	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-11В-12В_20мВ_20мкс_шаг_0,1	- OK
# №69	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-10В_200мВ_20мкс_шаг_0,1	- OK
# №70	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-11В_200мВ_20мкс_шаг_0,1	- OK
# №71	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-12В_200мВ_20мкс_шаг_0,1	- OK
# №72	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-2В_100мВ_20мкс_шаг_0,1	- OK
# №73	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-3В_200мВ_20мкс_шаг_0,1	- OK
# №74	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-4В_200мВ_20мкс_шаг_0,1	- OK
# №75	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-5В_200мВ_20мкс_шаг_0,1	- OK
# №76	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-6В_200мВ_20мкс_шаг_0,1	- OK
# №77	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-7В_200мВ_20мкс_шаг_0,1	- OK
# №78	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-8В_200мВ_20мкс_шаг_0,1	- OK
# №79	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-1В-9В_200мВ_20мкс_шаг_0,1	- OK
# №80	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-10В_200мВ_20мкс_шаг_0,1	- OK
# №81	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-11В_200мВ_20мкс_шаг_0,1	- OK
# №82	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-12В_200мВ_20мкс_шаг_0,1	- OK
# №83	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-3В_50мВ_20мкс_шаг_0,1	- OK
# №84	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-4В_100мВ_20мкс_шаг_0,1	- OK
# №85	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-5В_200мВ_20мкс_шаг_0,1	- OK
# №86	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-6В_200мВ_20мкс_шаг_0,1	- OK
# №87	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-7В_200мВ_20мкс_шаг_0,1	- OK
# №88	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-8В_200мВ_20мкс_шаг_0,1	- OK
# №89	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-2В-9В_200мВ_20мкс_шаг_0,1	- OK
# №90	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-10В_200мВ_20мкс_шаг_0,1	- OK
# №91	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-11В_200мВ_20мкс_шаг_0,1	- OK
# №92	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-12В_200мВ_20мкс_шаг_0,1	- OK
# №93	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-4В_50мВ_20мкс_шаг_0,1	- OK
# №94	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-5В_100мВ_20мкс_шаг_0,1	- OK
# №95	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-6В_100мВ_20мкс_шаг_0,1	- OK
# №96	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-7В_200мВ_20мкс_шаг_0,1	- OK
# №97	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-8В_200мВ_20мкс_шаг_0,1	- OK
# №98	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-3В-9В_200мВ_20мкс_шаг_0,1	- OK
# №99	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-10В_200мВ_20мкс_шаг_0,1	- OK
# №100	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-11В_200мВ_20мкс_шаг_0,1	- OK
# №101	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-12В_200мВ_20мкс_шаг_0,1	- OK
# №102	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-5В_50мВ_20мкс_шаг_0,1	- OK
# №103	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-6В_100мВ_20мкс_шаг_0,1	- OK
# №104	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-7В_100мВ_20мкс_шаг_0,1	- OK
# №105	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-8В_100мВ_20мкс_шаг_0,1	- OK
# №106	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-4В-9В_200мВ_20мкс_шаг_0,1	- OK
# №107	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-10В_100мВ_20мкс_шаг_0,1	- OK
# №108	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-11В_100мВ_20мкс_шаг_0,1	- OK
# №109	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-12В_200мВ_20мкс_шаг_0,1	- OK
# №110	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-6В_20мВ_20мкс_шаг_0,1	- OK
# №111	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-7В_50мВ_20мкс_шаг_0,1	- OK
# №112	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-8В_100мВ_20мкс_шаг_0,1	- OK
# №113	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-5В-9В_100мВ_20мкс_шаг_0,1	- OK
# №114	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-10В_100мВ_20мкс_шаг_0,1	- OK
# №115	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-11В_100мВ_20мкс_шаг_0,1	- OK
# №116	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-12В_100мВ_20мкс_шаг_0,1	- OK
# №117	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-7В_20мВ_20мкс_шаг_0,1	- OK
# №118	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-8В_50мВ_20мкс_шаг_0,1	- OK
# №119	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-6В-9В_100мВ_20мкс_шаг_0,1	- OK
# №120	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-7В-10В_100мВ_20мкс_шаг_0,1	- OK
# №121	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-7В-11В_100мВ_20мкс_шаг_0,1	- OK
# №122	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-7В-12В_100мВ_20мкс_шаг_0,1	- OK
# №123	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-7В-8В_20мВ_20мкс_шаг_0,1	- OK
# №124	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-7В-9В_50мВ_20мкс_шаг_0,1	- OK
# №125	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-8В-10В_50мВ_20мкс_шаг_0,1	- OK
# №126	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-8В-11В_50мВ_20мкс_шаг_0,1	- OK
# №127	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-8В-12В_100мВ_20мкс_шаг_0,1	- OK
# №128	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-8В-9В_20мВ_20мкс_шаг_0,1	- OK
# №129	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-9В-10В_20мВ_20мкс_шаг_0,1	- OK
# №130	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-9В-11В_20мВ_20мкс_шаг_0,1	- OK
# №131	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_+30С_-9В-12В_50мВ_20мкс_шаг_0,1	- OK
# №132	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-10В-11В_10мВ_20мкс_шаг_0,1	- OK
# №133	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-10В-12В_20мВ_20мкс_шаг_0,1	- OK
# №134	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-11В-12В_10мВ_20мкс_шаг_0,1	- OK
# №135	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-10В_200мВ_20мкс_шаг_0,1	- OK
# №136	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-11В_200мВ_20мкс_шаг_0,1	- OK
# №137	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-12В_200мВ_20мкс_шаг_0,1	- OK
# №138	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-2В_50мВ_20мкс_шаг_0,1	- OK
# №139	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-3В_100мВ_20мкс_шаг_0,1	- OK
# №140	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-4В_100мВ_20мкс_шаг_0,1	- OK
# №141	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-5В_200мВ_20мкс_шаг_0,1	- OK
# №142	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-6В_200мВ_20мкс_шаг_0,1	- OK
# №143	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-7В_200мВ_20мкс_шаг_0,1	- OK
# №144	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-8В_200мВ_20мкс_шаг_0,1	- OK
# №145	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-1В-9В_200мВ_20мкс_шаг_0,1	- OK
# №146	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-10В_100мВ_20мкс_шаг_0,1	- OK
# №147	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-11В_100мВ_20мкс_шаг_0,1	- OK
# №148	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-12В_200мВ_20мкс_шаг_0,1	- OK
# №149	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-3В_20мВ_20мкс_шаг_0,1	- OK
# №150	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-4В_100мВ_20мкс_шаг_0,1	- OK
# №151	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-5В_100мВ_20мкс_шаг_0,1	- OK
# №152	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-6В_100мВ_20мкс_шаг_0,1	- OK
# №153	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-7В_100мВ_20мкс_шаг_0,1	- OK
# №154	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-8В_100мВ_20мкс_шаг_0,1	- OK
# №155	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-2В-9В_100мВ_20мкс_шаг_0,1	- OK
# №156	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-10В_100мВ_20мкс_шаг_0,1	- OK
# №157	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-11В_100мВ_100мкс_шаг_0,1	- OK
# №158	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-12В_100мВ_20мкс_шаг_0,1	- OK
# №159	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-4В_20мВ_20мкс_шаг_0,1	- OK
# №160	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-5В_50мВ_20мкс_шаг_0,1	- OK
# №161	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-6В_100мВ_20мкс_шаг_0,1	- OK
# №162	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-7В_100мВ_20мкс_шаг_0,1	- OK
# №163	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-8В_100мВ_20мкс_шаг_0,1	- OK
# №164	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-3В-9В_100мВ_20мкс_шаг_0,1	- OK
# №165	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-10В_100мВ_20мкс_шаг_0,1	- OK
# №166	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-11В_100мВ_20мкс_шаг_0,1	- OK
# №167	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-12В_100мВ_20мкс_шаг_0,1	- OK
# №168	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-5В_20мВ_20мкс_шаг_0,1	- OK
# №169	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-6В_50мВ_20мкс_шаг_0,1	- OK
# №170	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-7В_50мВ_20мкс_шаг_0,1	- OK
# №171	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-8В_100мВ_20мкс_шаг_0,1	- OK
# №172	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-4В-9В_100мВ_20мкс_шаг_0,1	- OK
# №173	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-10В_100мВ_20мкс_шаг_0,1	- OK
# №174	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-11В_100мВ_20мкс_шаг_0,1	- OK
# №175	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-12В_100мВ_20мкс_шаг_0,1	- OK
# №176	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-6В_20мВ_20мкс_шаг_0,1	- OK
# №177	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-7В_50мВ_20мкс_шаг_0,1	- OK
# №178	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-8В_100мВ_20мкс_шаг_0,1	- OK
# №179	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-5В-9В_100мВ_20мкс_шаг_0,1	- OK
# №180	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-10В_100мВ_20мкс_шаг_0,1	- OK
# №181	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-11В_100мВ_20мкс_шаг_0,1	- OK
# №182	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-12В_100мВ_20мкс_шаг_0,1	- OK
# №183	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-7В_20мВ_20мкс_шаг_0,1	- OK
# №184	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-8В_50мВ_20мкс_шаг_0,1	- OK
# №185	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-6В-9В_50мВ_20мкс_шаг_0,1	- OK
# №186	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-7В-10В_50мВ_20мкс_шаг_0,1	- OK
# №187	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-7В-11В_50мВ_20мкс_шаг_0,1	- OK
# №188	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-7В-12В_100мВ_20мкс_шаг_0,1	- OK
# №189	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-7В-8В_20мВ_20мкс_шаг_0,1	- OK
# №190	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-7В-9В_50мВ_20мкс_шаг_0,1	- OK
# №191	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-8В-10В_20мВ_20мкс_шаг_0,1	- OK
# №192	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-8В-11В_50мВ_20мкс_шаг_0,1	- OK
# №193	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-8В-12В_50мВ_20мкс_шаг_0,1	- OK
# №194	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-8В-9В_20мВ_20мкс_шаг_0,1	- OK
# №195	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-9В-10В_10мВ_20мкс_шаг_0,1	- OK
# №196	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-9В-11В_20мВ_20мкс_шаг_0,1	- OK
# №197	КТ117№1_п1(база 2)_2500Гц-1Гц_1пФ_-10С_-9В-12В_50мВ_20мкс_шаг_0,1	- OK
